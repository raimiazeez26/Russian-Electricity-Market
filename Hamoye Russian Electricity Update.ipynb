# %% [markdown]
# # Russian Wholesale Electricity Market

# %% [markdown]
# ## Context
#
# On 1st September 2006, the Wholesale Electricity and Capacity Market was launched in Russia. The nodal pricing system is applied to the wholesale market: each node gets an individual price value for a certain hour. For the price analysis and forecast problem, the analyst uses the weighted average of the nodal prices for certain territory such as price zone, united energy system and others. More details about the Wholesale Electricity and Capacity Market of Russia you will find in my latest paper The Three-Headed Dragon: Electricity, Trading, Analysis.﻿

# %% [markdown]
# ## Content
#
# The data files include
#
# * the weighted average of the nodal day ahead prices for the European and Siberian price zones of the market;
# * the weighted average of the nodal day ahead prices for six United Energy Systems: NorthWest, Centre, Ural, South, Middle Volga and Siberia;
# * the day ahead scheduled volume for the European and Siberian price zones;
# * the weighted average of the nodal intraday prices for three United Energy Systems: NorthWest, Centre and Siberia
#
# Time stamps are in Europe/Moscow timezone.
#
# For more details, please see [The Three-Headed Dragon: Electricity, Trading, Analysis](https://www.mbureau.energy/articles/three-headed-dragon-electricity-trading-analysis-first-head-electricity).

# %% [markdown]
# ## CHALLENGES
# Electricity is a commodity capable of being bought, sold, and traded. All nations are moving towards a
# Deregulated Electricity Market System where the competitors are allowed to buy and sell electricity by
# permitting market participants to invest in power plants and transmission lines. Also, it offers a broader
# range of renewable energy options - the need of the hour.
# This system has paved the way for Data Scientists/ Machine Learning Engineers to extensively participate in
# the growing dynamic energy management systems. The spectrum includes predicting energy requirements,
# prices, network grid analysis, etc.
#
# ## PROJECT DESCRIPTION: WHOLESALE ELECTRICITY MARKET DATASET
# Addressing the high demand for power, on the 1st of September 2006, the Wholesale Electricity and
# Capacity Market was launched in Russia. Now, both the price and electricity consumption forecast problem
# is highly important on the Wholesale Electricity Market. Thus, the questions:
#
# * What price should we expect tomorrow, next week, next year?
# * What electricity consumption should we expect tomorrow, next week, next year?
#
# It is important to employ analysts, ML Engineers, and Data Scientists to extract patterns from data to derive
# insights that could help different aspects of the operation.
#
# Reference : https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

sns.set()

# %%
#fetch files from directory
pathcwd = os.getcwd()
path = pathcwd + "/Project data/Russian Electricity Data 2006"
files = glob.glob(path + "/*.csv")
files
# Out:
# ['/Users/user/Documents/Data Science/Hamoye/Project data/Russian Electricity Data 2006/RU_Electricity_Market_UES_intraday_price.csv',
#  '/Users/user/Documents/Data Science/Hamoye/Project data/Russian Electricity Data 2006/RU_Electricity_Market_PZ_dayahead_price_volume.csv',
#  '/Users/user/Documents/Data Science/Hamoye/Project data/Russian Electricity Data 2006/RU_Electricity_Market_UES_dayahead_price.csv']

# %%
for file in files:
    print(file)
# Out:
# /Users/user/Documents/Data Science/Hamoye/Project data/Russian Electricity Data 2006/RU_Electricity_Market_UES_intraday_price.csv
# /Users/user/Documents/Data Science/Hamoye/Project data/Russian Electricity Data 2006/RU_Electricity_Market_PZ_dayahead_price_volume.csv
# /Users/user/Documents/Data Science/Hamoye/Project data/Russian Electricity Data 2006/RU_Electricity_Market_UES_dayahead_price.csv

# %%
UES_intraday_price = pd.read_csv(files[0])
PZ_dayahead_price_volume = pd.read_csv(files[1])
UES_dayahead_price = pd.read_csv(files[2])
UES_intraday_price.head()
# Out:
#            timestep  UES_Northwest  UES_Siberia  UES_Center
# 0  2017-01-01 00:00            767          918         982
# 1  2017-01-01 01:00            675          889         848
# 2  2017-01-01 02:00            717          933         920
# 3  2017-01-01 03:00            683          947         885
# 4  2017-01-01 04:00            633          934         829

# %%
def data_details(data):
    head = data.head()
    info = data.info()
    describe = data.describe()
    any_null = data.isnull().any()
    
    return (print(head),
                  print(info), 
                  print(describe),
                  print(any_null))

# %%
data_details(UES_intraday_price)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24072 entries, 0 to 24071
# Data columns (total 4 columns):
# timestep         24072 non-null object
# UES_Northwest    24072 non-null int64
# UES_Siberia      24072 non-null int64
# UES_Center       24072 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 752.4+ KB
#            timestep  UES_Northwest  UES_Siberia  UES_Center
# 0  2017-01-01 00:00            767          918         982
# 1  2017-01-01 01:00            675          889         848
# 2  2017-01-01 02:00            717          933         920
# 3  2017-01-01 03:00            683          947         885
# 4  2017-01-01 04:00            633          934         829
# None
#        UES_Northwest   UES_Siberia    UES_Center
# count   24072.000000  24072.000000  24072.000000
# mean      990.692921    794.586200   1210.754944
# std       316.709637    259.351579    356.775935
# min         0.000000      0.000000      0.000000
# 25%       792.000000    693.000000    967.000000
# 50%       991.000000    856.000000   1225.000000
# 75%      1200.000000    965.000000   1477.000000
# max      6707.000000   1527.000000   6845.000000
# timestep         False
# UES_Northwest    False
# UES_Siberia      False
# UES_Center       False
# dtype: bool
# (None, None, None, None)

# %% [markdown]
# ## 0 Minimum Values ????
# Notice that the minimum values for all three regions is Zero (0). Since we are talking about prices it is mostly unlikely that there are hours/periods where electricity is free. So we assume these are errors.
#
# Or does that mean there was no power supply within those hours?? THEM DEY TAKE LIGHT FOR RUSSIA??????
#
# Let's count the number of Zero values in each region.
#
#
# After some research, I found that:
#
# `"If a consumer leaves the price cells empty, it declares its intention to buy electricity at any market price. This type of bid is called a price independent bid. Such bids reflect inelastic demand, as discussed earlier. In 2017 in Russia 99.5% of bids were price independent."`
#
# This explains why there are lots of zero values, especially in 2017

# %%
count = 0
count1 = 0
count2 = 0
for row, i in UES_intraday_price.iterrows():
    if i[1] == 0:
        count += 1
    if i[2] == 0:
        count1 += 1
    if i[3] == 0:
        count2 += 1
print (f"There are {count} - 0 values in UES_Northwest")
print (f"There are {count1} - 0 values in UES_Siberia")
print (f"There are {count2} - 0 values in UES_Center")
# Out:
# There are 63 - 0 values in UES_Northwest
# There are 642 - 0 values in UES_Siberia
# There are 73 - 0 values in UES_Center

# %%
# print timestamp of each zero values

for row, i in UES_intraday_price.iterrows():
    if i[1] == 0:
        print (i)
# Out:
# timestep         2017-01-26 00:00
# UES_Northwest                   0
# UES_Siberia                   309
# UES_Center                      0
# Name: 600, dtype: object
# timestep         2017-01-26 01:00
# UES_Northwest                   0
# UES_Siberia                   318
# UES_Center                      1
# Name: 601, dtype: object
# timestep         2017-04-16 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 2543, dtype: object
# timestep         2017-04-21 01:00
# UES_Northwest                   0
# UES_Siberia                   304
# UES_Center                      0
# Name: 2641, dtype: object
# timestep         2017-04-28 02:00
# UES_Northwest                   0
# UES_Siberia                   381
# UES_Center                      0
# Name: 2810, dtype: object
# timestep         2017-05-01 03:00
# UES_Northwest                   0
# UES_Siberia                   381
# UES_Center                      0
# Name: 2883, dtype: object
# timestep         2017-05-03 04:00
# UES_Northwest                   0
# UES_Siberia                   286
# UES_Center                      0
# Name: 2932, dtype: object
# timestep         2017-05-04 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 2975, dtype: object
# timestep         2017-05-22 02:00
# UES_Northwest                   0
# UES_Siberia                   298
# UES_Center                      0
# Name: 3386, dtype: object
# timestep         2017-05-22 03:00
# UES_Northwest                   0
# UES_Siberia                   308
# UES_Center                      0
# Name: 3387, dtype: object
# timestep         2017-05-23 00:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 3408, dtype: object
# timestep         2017-05-25 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 3479, dtype: object
# timestep         2017-05-30 00:00
# UES_Northwest                   0
# UES_Siberia                   110
# UES_Center                      0
# Name: 3576, dtype: object
# timestep         2017-05-30 01:00
# UES_Northwest                   0
# UES_Siberia                    61
# UES_Center                      0
# Name: 3577, dtype: object
# timestep         2017-05-30 02:00
# UES_Northwest                   0
# UES_Siberia                   311
# UES_Center                      0
# Name: 3578, dtype: object
# timestep         2017-05-31 03:00
# UES_Northwest                   0
# UES_Siberia                    61
# UES_Center                      0
# Name: 3603, dtype: object
# timestep         2017-06-08 03:00
# UES_Northwest                   0
# UES_Siberia                   358
# UES_Center                     51
# Name: 3795, dtype: object
# timestep         2017-06-08 04:00
# UES_Northwest                   0
# UES_Siberia                   405
# UES_Center                     15
# Name: 3796, dtype: object
# timestep         2017-06-09 02:00
# UES_Northwest                   0
# UES_Siberia                   432
# UES_Center                      2
# Name: 3818, dtype: object
# timestep         2017-06-09 03:00
# UES_Northwest                   0
# UES_Siberia                   503
# UES_Center                      1
# Name: 3819, dtype: object
# timestep         2017-06-13 02:00
# UES_Northwest                   0
# UES_Siberia                   312
# UES_Center                      0
# Name: 3914, dtype: object
# timestep         2017-06-13 04:00
# UES_Northwest                   0
# UES_Siberia                   537
# UES_Center                      0
# Name: 3916, dtype: object
# timestep         2017-06-14 02:00
# UES_Northwest                   0
# UES_Siberia                   439
# UES_Center                      0
# Name: 3938, dtype: object
# timestep         2017-06-14 03:00
# UES_Northwest                   0
# UES_Siberia                   574
# UES_Center                      0
# Name: 3939, dtype: object
# timestep         2017-07-03 03:00
# UES_Northwest                   0
# UES_Siberia                   368
# UES_Center                      1
# Name: 4395, dtype: object
# timestep         2017-07-04 03:00
# UES_Northwest                   0
# UES_Siberia                    82
# UES_Center                      0
# Name: 4419, dtype: object
# timestep         2017-07-04 04:00
# UES_Northwest                   0
# UES_Siberia                   358
# UES_Center                      0
# Name: 4420, dtype: object
# timestep         2017-07-05 03:00
# UES_Northwest                   0
# UES_Siberia                   355
# UES_Center                      0
# Name: 4443, dtype: object
# timestep         2017-07-12 01:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4609, dtype: object
# timestep         2017-07-12 02:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4610, dtype: object
# timestep         2017-07-12 03:00
# UES_Northwest                   0
# UES_Siberia                   368
# UES_Center                      0
# Name: 4611, dtype: object
# timestep         2017-07-12 04:00
# UES_Northwest                   0
# UES_Siberia                   369
# UES_Center                      0
# Name: 4612, dtype: object
# timestep         2017-07-13 00:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4632, dtype: object
# timestep         2017-07-13 01:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4633, dtype: object
# timestep         2017-07-13 02:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4634, dtype: object
# timestep         2017-07-13 03:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4635, dtype: object
# timestep         2017-07-13 04:00
# UES_Northwest                   0
# UES_Siberia                    26
# UES_Center                      0
# Name: 4636, dtype: object
# timestep         2017-07-18 03:00
# UES_Northwest                   0
# UES_Siberia                   358
# UES_Center                      0
# Name: 4755, dtype: object
# timestep         2017-08-08 03:00
# UES_Northwest                   0
# UES_Siberia                   123
# UES_Center                      3
# Name: 5259, dtype: object
# timestep         2017-08-08 04:00
# UES_Northwest                   0
# UES_Siberia                   388
# UES_Center                      3
# Name: 5260, dtype: object
# timestep         2017-08-10 03:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 5307, dtype: object
# timestep         2017-08-17 01:00
# UES_Northwest                   0
# UES_Siberia                   649
# UES_Center                      1
# Name: 5473, dtype: object
# timestep         2017-10-30 00:00
# UES_Northwest                   0
# UES_Siberia                   268
# UES_Center                      0
# Name: 7248, dtype: object
# timestep         2017-11-04 02:00
# UES_Northwest                   0
# UES_Siberia                   436
# UES_Center                      1
# Name: 7370, dtype: object
# timestep         2017-11-04 23:00
# UES_Northwest                   0
# UES_Siberia                     1
# UES_Center                      1
# Name: 7391, dtype: object
# timestep         2017-11-23 00:00
# UES_Northwest                   0
# UES_Siberia                   282
# UES_Center                      0
# Name: 7824, dtype: object
# timestep         2017-12-14 23:00
# UES_Northwest                   0
# UES_Siberia                   851
# UES_Center                      0
# Name: 8351, dtype: object
# timestep         2018-04-09 04:00
# UES_Northwest                   0
# UES_Siberia                   419
# UES_Center                      0
# Name: 11116, dtype: object
# timestep         2018-04-16 01:00
# UES_Northwest                   0
# UES_Siberia                   386
# UES_Center                      0
# Name: 11281, dtype: object
# timestep         2018-04-18 01:00
# UES_Northwest                   0
# UES_Siberia                   409
# UES_Center                      1
# Name: 11329, dtype: object
# timestep         2018-04-18 03:00
# UES_Northwest                   0
# UES_Siberia                   417
# UES_Center                      0
# Name: 11331, dtype: object
# timestep         2018-05-04 02:00
# UES_Northwest                   0
# UES_Siberia                   469
# UES_Center                      0
# Name: 11714, dtype: object
# timestep         2018-05-04 03:00
# UES_Northwest                   0
# UES_Siberia                   824
# UES_Center                      1
# Name: 11715, dtype: object
# timestep         2018-05-07 03:00
# UES_Northwest                   0
# UES_Siberia                   866
# UES_Center                      1
# Name: 11787, dtype: object
# timestep         2018-05-20 04:00
# UES_Northwest                   0
# UES_Siberia                   805
# UES_Center                      0
# Name: 12100, dtype: object
# timestep         2018-11-18 02:00
# UES_Northwest                   0
# UES_Siberia                   833
# UES_Center                    540
# Name: 16466, dtype: object
# timestep         2018-11-18 03:00
# UES_Northwest                   0
# UES_Siberia                   834
# UES_Center                    538
# Name: 16467, dtype: object
# timestep         2019-05-12 04:00
# UES_Northwest                   0
# UES_Siberia                  1032
# UES_Center                      0
# Name: 20668, dtype: object
# timestep         2019-07-02 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      3
# Name: 21911, dtype: object
# timestep         2019-08-26 03:00
# UES_Northwest                   0
# UES_Siberia                   227
# UES_Center                      0
# Name: 23211, dtype: object
# timestep         2019-09-10 02:00
# UES_Northwest                   0
# UES_Siberia                   117
# UES_Center                      0
# Name: 23570, dtype: object
# timestep         2019-09-30 00:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 24048, dtype: object
# timestep         2019-09-30 01:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 24049, dtype: object

# %%
for row, i in UES_intraday_price.iterrows():
    if i[2] == 0:
        print (i)
# Out:
# timestep         2017-01-11 23:00
# UES_Northwest                 248
# UES_Siberia                     0
# UES_Center                    301
# Name: 263, dtype: object
# timestep         2017-01-16 22:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      4
# Name: 382, dtype: object
# timestep         2017-01-16 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      5
# Name: 383, dtype: object
# timestep         2017-01-17 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      2
# Name: 407, dtype: object
# timestep         2017-01-23 22:00
# UES_Northwest                   2
# UES_Siberia                     0
# UES_Center                      2
# Name: 550, dtype: object
# timestep         2017-01-23 23:00
# UES_Northwest                  16
# UES_Siberia                     0
# UES_Center                     21
# Name: 551, dtype: object
# timestep         2017-01-24 22:00
# UES_Northwest                  12
# UES_Siberia                     0
# UES_Center                     15
# Name: 574, dtype: object
# timestep         2017-01-25 23:00
# UES_Northwest                 244
# UES_Siberia                     0
# UES_Center                    310
# Name: 599, dtype: object
# timestep         2017-01-26 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      1
# Name: 623, dtype: object
# timestep         2017-01-28 23:00
# UES_Northwest                   6
# UES_Siberia                     0
# UES_Center                      4
# Name: 671, dtype: object
# timestep         2017-01-29 22:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      2
# Name: 694, dtype: object
# timestep         2017-01-29 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      1
# Name: 695, dtype: object
# timestep         2017-01-30 22:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      1
# Name: 718, dtype: object
# timestep         2017-01-30 23:00
# UES_Northwest                   2
# UES_Siberia                     0
# UES_Center                      2
# Name: 719, dtype: object
# timestep         2017-02-04 22:00
# UES_Northwest                   6
# UES_Siberia                     0
# UES_Center                      4
# Name: 838, dtype: object
# timestep         2017-02-04 23:00
# UES_Northwest                   6
# UES_Siberia                     0
# UES_Center                      4
# Name: 839, dtype: object
# timestep         2017-02-05 22:00
# UES_Northwest                  29
# UES_Siberia                     0
# UES_Center                     33
# Name: 862, dtype: object
# timestep         2017-02-05 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      2
# Name: 863, dtype: object
# timestep         2017-02-08 23:00
# UES_Northwest                   9
# UES_Siberia                     0
# UES_Center                     12
# Name: 935, dtype: object
# timestep         2017-02-12 22:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      2
# Name: 1030, dtype: object
# timestep         2017-02-12 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      1
# Name: 1031, dtype: object
# timestep         2017-02-14 22:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      2
# Name: 1078, dtype: object
# timestep         2017-02-14 23:00
# UES_Northwest                   2
# UES_Siberia                     0
# UES_Center                      2
# Name: 1079, dtype: object
# timestep         2017-02-15 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      1
# Name: 1103, dtype: object
# timestep         2017-02-18 22:00
# UES_Northwest                  11
# UES_Siberia                     0
# UES_Center                     10
# Name: 1174, dtype: object
# timestep         2017-02-20 22:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      5
# Name: 1222, dtype: object
# timestep         2017-02-20 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      1
# Name: 1223, dtype: object
# timestep         2017-02-21 23:00
# UES_Northwest                   2
# UES_Siberia                     0
# UES_Center                      2
# Name: 1247, dtype: object
# timestep         2017-02-22 22:00
# UES_Northwest                 440
# UES_Siberia                     0
# UES_Center                    525
# Name: 1270, dtype: object
# timestep         2017-02-22 23:00
# UES_Northwest                 291
# UES_Siberia                     0
# UES_Center                    361
# Name: 1271, dtype: object
# timestep         2017-02-27 23:00
# UES_Northwest                 611
# UES_Siberia                     0
# UES_Center                    772
# Name: 1391, dtype: object
# timestep         2017-03-05 23:00
# UES_Northwest                   6
# UES_Siberia                     0
# UES_Center                      4
# Name: 1535, dtype: object
# timestep         2017-03-07 23:00
# UES_Northwest                   6
# UES_Siberia                     0
# UES_Center                      4
# Name: 1583, dtype: object
# timestep         2017-03-08 20:00
# UES_Northwest                  24
# UES_Siberia                     0
# UES_Center                      5
# Name: 1604, dtype: object
# timestep         2017-03-11 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                     10
# Name: 1679, dtype: object
# timestep         2017-03-12 23:00
# UES_Northwest                  16
# UES_Siberia                     0
# UES_Center                     19
# Name: 1703, dtype: object
# timestep         2017-03-13 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      2
# Name: 1727, dtype: object
# timestep         2017-03-14 20:00
# UES_Northwest                 743
# UES_Siberia                     0
# UES_Center                    962
# Name: 1748, dtype: object
# timestep         2017-03-16 21:00
# UES_Northwest                 853
# UES_Siberia                     0
# UES_Center                   1090
# Name: 1797, dtype: object
# timestep         2017-03-20 23:00
# UES_Northwest                 533
# UES_Siberia                     0
# UES_Center                    585
# Name: 1895, dtype: object
# timestep         2017-03-22 22:00
# UES_Northwest                 571
# UES_Siberia                     0
# UES_Center                    722
# Name: 1942, dtype: object
# timestep         2017-03-22 23:00
# UES_Northwest                 708
# UES_Siberia                     0
# UES_Center                    708
# Name: 1943, dtype: object
# timestep         2017-03-23 19:00
# UES_Northwest                 946
# UES_Siberia                     0
# UES_Center                   1211
# Name: 1963, dtype: object
# timestep         2017-03-23 20:00
# UES_Northwest                 736
# UES_Siberia                     0
# UES_Center                    940
# Name: 1964, dtype: object
# timestep         2017-03-23 21:00
# UES_Northwest                 750
# UES_Siberia                     0
# UES_Center                    937
# Name: 1965, dtype: object
# timestep         2017-03-23 22:00
# UES_Northwest                 711
# UES_Siberia                     0
# UES_Center                    873
# Name: 1966, dtype: object
# timestep         2017-03-23 23:00
# UES_Northwest                 759
# UES_Siberia                     0
# UES_Center                    943
# Name: 1967, dtype: object
# timestep         2017-03-24 19:00
# UES_Northwest                1036
# UES_Siberia                     0
# UES_Center                   1372
# Name: 1987, dtype: object
# timestep         2017-03-24 21:00
# UES_Northwest                 909
# UES_Siberia                     0
# UES_Center                   1171
# Name: 1989, dtype: object
# timestep         2017-03-24 22:00
# UES_Northwest                 827
# UES_Siberia                     0
# UES_Center                   1044
# Name: 1990, dtype: object
# timestep         2017-03-24 23:00
# UES_Northwest                 743
# UES_Siberia                     0
# UES_Center                    946
# Name: 1991, dtype: object
# timestep         2017-03-25 22:00
# UES_Northwest                 640
# UES_Siberia                     0
# UES_Center                    809
# Name: 2014, dtype: object
# timestep         2017-03-26 23:00
# UES_Northwest                 685
# UES_Siberia                     0
# UES_Center                    734
# Name: 2039, dtype: object
# timestep         2017-03-27 18:00
# UES_Northwest                1090
# UES_Siberia                     0
# UES_Center                   1253
# Name: 2058, dtype: object
# timestep         2017-03-27 19:00
# UES_Northwest                1154
# UES_Siberia                     0
# UES_Center                   1302
# Name: 2059, dtype: object
# timestep         2017-03-27 20:00
# UES_Northwest                 843
# UES_Siberia                     0
# UES_Center                    943
# Name: 2060, dtype: object
# timestep         2017-03-27 21:00
# UES_Northwest                 885
# UES_Siberia                     0
# UES_Center                    951
# Name: 2061, dtype: object
# timestep         2017-03-27 22:00
# UES_Northwest                 457
# UES_Siberia                     0
# UES_Center                    564
# Name: 2062, dtype: object
# timestep         2017-03-27 23:00
# UES_Northwest                   5
# UES_Siberia                     0
# UES_Center                      6
# Name: 2063, dtype: object
# timestep         2017-03-28 10:00
# UES_Northwest                1080
# UES_Siberia                     0
# UES_Center                   1229
# Name: 2074, dtype: object
# timestep         2017-03-28 18:00
# UES_Northwest                 964
# UES_Siberia                     0
# UES_Center                   1278
# Name: 2082, dtype: object
# timestep         2017-03-28 20:00
# UES_Northwest                 702
# UES_Siberia                     0
# UES_Center                    909
# Name: 2084, dtype: object
# timestep         2017-03-28 21:00
# UES_Northwest                 739
# UES_Siberia                     0
# UES_Center                    808
# Name: 2085, dtype: object
# timestep         2017-03-28 22:00
# UES_Northwest                 461
# UES_Siberia                     0
# UES_Center                    582
# Name: 2086, dtype: object
# timestep         2017-03-28 23:00
# UES_Northwest                 410
# UES_Siberia                     0
# UES_Center                    516
# Name: 2087, dtype: object
# timestep         2017-03-29 09:00
# UES_Northwest                1115
# UES_Siberia                     0
# UES_Center                   1379
# Name: 2097, dtype: object
# timestep         2017-03-29 11:00
# UES_Northwest                 990
# UES_Siberia                     0
# UES_Center                   1099
# Name: 2099, dtype: object
# timestep         2017-03-29 13:00
# UES_Northwest                1069
# UES_Siberia                     0
# UES_Center                   1167
# Name: 2101, dtype: object
# timestep         2017-03-29 19:00
# UES_Northwest                1035
# UES_Siberia                     0
# UES_Center                   1157
# Name: 2107, dtype: object
# timestep         2017-03-29 20:00
# UES_Northwest                 613
# UES_Siberia                     0
# UES_Center                    772
# Name: 2108, dtype: object
# timestep         2017-03-29 21:00
# UES_Northwest                 584
# UES_Siberia                     0
# UES_Center                    725
# Name: 2109, dtype: object
# timestep         2017-03-29 22:00
# UES_Northwest                 431
# UES_Siberia                     0
# UES_Center                    524
# Name: 2110, dtype: object
# timestep         2017-03-29 23:00
# UES_Northwest                 430
# UES_Siberia                     0
# UES_Center                    522
# Name: 2111, dtype: object
# timestep         2017-03-30 20:00
# UES_Northwest                 595
# UES_Siberia                     0
# UES_Center                    788
# Name: 2132, dtype: object
# timestep         2017-03-30 21:00
# UES_Northwest                 599
# UES_Siberia                     0
# UES_Center                    770
# Name: 2133, dtype: object
# timestep         2017-03-30 22:00
# UES_Northwest                 596
# UES_Siberia                     0
# UES_Center                    756
# Name: 2134, dtype: object
# timestep         2017-03-31 18:00
# UES_Northwest                 695
# UES_Siberia                     0
# UES_Center                    914
# Name: 2154, dtype: object
# timestep         2017-03-31 22:00
# UES_Northwest                 405
# UES_Siberia                     0
# UES_Center                    505
# Name: 2158, dtype: object
# timestep         2017-03-31 23:00
# UES_Northwest                  45
# UES_Siberia                     0
# UES_Center                     35
# Name: 2159, dtype: object
# timestep         2017-04-01 18:00
# UES_Northwest                1134
# UES_Siberia                     0
# UES_Center                   1226
# Name: 2178, dtype: object
# timestep         2017-04-01 20:00
# UES_Northwest                1131
# UES_Siberia                     0
# UES_Center                   1209
# Name: 2180, dtype: object
# timestep         2017-04-01 21:00
# UES_Northwest                 952
# UES_Siberia                     0
# UES_Center                   1018
# Name: 2181, dtype: object
# timestep         2017-04-01 22:00
# UES_Northwest                 901
# UES_Siberia                     0
# UES_Center                    952
# Name: 2182, dtype: object
# timestep         2017-04-01 23:00
# UES_Northwest                 840
# UES_Siberia                     0
# UES_Center                    906
# Name: 2183, dtype: object
# timestep         2017-04-02 21:00
# UES_Northwest                1041
# UES_Siberia                     0
# UES_Center                   1122
# Name: 2205, dtype: object
# timestep         2017-04-02 22:00
# UES_Northwest                 933
# UES_Siberia                     0
# UES_Center                   1004
# Name: 2206, dtype: object
# timestep         2017-04-02 23:00
# UES_Northwest                 837
# UES_Siberia                     0
# UES_Center                    902
# Name: 2207, dtype: object
# timestep         2017-04-10 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      5
# Name: 2399, dtype: object
# timestep         2017-04-12 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      4
# Name: 2447, dtype: object
# timestep         2017-04-16 22:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      1
# Name: 2542, dtype: object
# timestep         2017-04-16 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 2543, dtype: object
# timestep         2017-04-19 22:00
# UES_Northwest                 607
# UES_Siberia                     0
# UES_Center                    562
# Name: 2614, dtype: object
# timestep         2017-04-19 23:00
# UES_Northwest                 311
# UES_Siberia                     0
# UES_Center                    392
# Name: 2615, dtype: object
# timestep         2017-04-27 21:00
# UES_Northwest                 842
# UES_Siberia                     0
# UES_Center                   1049
# Name: 2805, dtype: object
# timestep         2017-04-27 22:00
# UES_Northwest                 627
# UES_Siberia                     0
# UES_Center                    714
# Name: 2806, dtype: object
# timestep         2017-04-28 22:00
# UES_Northwest                 640
# UES_Siberia                     0
# UES_Center                    809
# Name: 2830, dtype: object
# timestep         2017-04-28 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      0
# Name: 2831, dtype: object
# timestep         2017-05-04 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 2975, dtype: object
# timestep         2017-05-10 20:00
# UES_Northwest                1145
# UES_Siberia                     0
# UES_Center                   1591
# Name: 3116, dtype: object
# timestep         2017-05-10 21:00
# UES_Northwest                1128
# UES_Siberia                     0
# UES_Center                   1560
# Name: 3117, dtype: object
# timestep         2017-05-10 22:00
# UES_Northwest                 904
# UES_Siberia                     0
# UES_Center                   1194
# Name: 3118, dtype: object
# timestep         2017-05-10 23:00
# UES_Northwest                 652
# UES_Siberia                     0
# UES_Center                    836
# Name: 3119, dtype: object
# timestep         2017-05-11 18:00
# UES_Northwest                1159
# UES_Siberia                     0
# UES_Center                   1577
# Name: 3138, dtype: object
# timestep         2017-05-11 20:00
# UES_Northwest                 862
# UES_Siberia                     0
# UES_Center                   2000
# Name: 3140, dtype: object
# timestep         2017-05-11 21:00
# UES_Northwest                1065
# UES_Siberia                     0
# UES_Center                   1577
# Name: 3141, dtype: object
# timestep         2017-05-11 23:00
# UES_Northwest                 790
# UES_Siberia                     0
# UES_Center                    889
# Name: 3143, dtype: object
# timestep         2017-05-13 20:00
# UES_Northwest                1157
# UES_Siberia                     0
# UES_Center                   1512
# Name: 3188, dtype: object
# timestep         2017-05-13 21:00
# UES_Northwest                1136
# UES_Siberia                     0
# UES_Center                   1397
# Name: 3189, dtype: object
# timestep         2017-05-13 22:00
# UES_Northwest                 894
# UES_Siberia                     0
# UES_Center                   1072
# Name: 3190, dtype: object
# timestep         2017-05-13 23:00
# UES_Northwest                 464
# UES_Siberia                     0
# UES_Center                    533
# Name: 3191, dtype: object
# timestep         2017-05-14 23:00
# UES_Northwest                 336
# UES_Siberia                     0
# UES_Center                    394
# Name: 3215, dtype: object
# timestep         2017-05-15 19:00
# UES_Northwest                 989
# UES_Siberia                     0
# UES_Center                   1206
# Name: 3235, dtype: object
# timestep         2017-05-15 20:00
# UES_Northwest                1115
# UES_Siberia                     0
# UES_Center                   1409
# Name: 3236, dtype: object
# timestep         2017-05-15 21:00
# UES_Northwest                1346
# UES_Siberia                     0
# UES_Center                   1220
# Name: 3237, dtype: object
# timestep         2017-05-15 22:00
# UES_Northwest                1113
# UES_Siberia                     0
# UES_Center                    914
# Name: 3238, dtype: object
# timestep         2017-05-15 23:00
# UES_Northwest                 901
# UES_Siberia                     0
# UES_Center                    505
# Name: 3239, dtype: object
# timestep         2017-05-16 22:00
# UES_Northwest                 955
# UES_Siberia                     0
# UES_Center                    912
# Name: 3262, dtype: object
# timestep         2017-05-17 21:00
# UES_Northwest                1095
# UES_Siberia                     0
# UES_Center                   1389
# Name: 3285, dtype: object
# timestep         2017-05-17 22:00
# UES_Northwest                 829
# UES_Siberia                     0
# UES_Center                   1027
# Name: 3286, dtype: object
# timestep         2017-05-17 23:00
# UES_Northwest                 437
# UES_Siberia                     0
# UES_Center                    531
# Name: 3287, dtype: object
# timestep         2017-05-18 19:00
# UES_Northwest                 989
# UES_Siberia                     0
# UES_Center                   1061
# Name: 3307, dtype: object
# timestep         2017-05-18 21:00
# UES_Northwest                1150
# UES_Siberia                     0
# UES_Center                   1257
# Name: 3309, dtype: object
# timestep         2017-05-18 22:00
# UES_Northwest                 893
# UES_Siberia                     0
# UES_Center                    935
# Name: 3310, dtype: object
# timestep         2017-05-23 00:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 3408, dtype: object
# timestep         2017-05-23 21:00
# UES_Northwest                1271
# UES_Siberia                     0
# UES_Center                   1402
# Name: 3429, dtype: object
# timestep         2017-05-23 22:00
# UES_Northwest                 871
# UES_Siberia                     0
# UES_Center                    928
# Name: 3430, dtype: object
# timestep         2017-05-24 00:00
# UES_Northwest                 643
# UES_Siberia                     0
# UES_Center                    693
# Name: 3432, dtype: object
# timestep         2017-05-24 21:00
# UES_Northwest                1202
# UES_Siberia                     0
# UES_Center                   1593
# Name: 3453, dtype: object
# timestep         2017-05-24 23:00
# UES_Northwest                 658
# UES_Siberia                     0
# UES_Center                    850
# Name: 3455, dtype: object
# timestep         2017-05-25 17:00
# UES_Northwest                 829
# UES_Siberia                     0
# UES_Center                    903
# Name: 3473, dtype: object
# timestep         2017-05-25 19:00
# UES_Northwest                 660
# UES_Siberia                     0
# UES_Center                    880
# Name: 3475, dtype: object
# timestep         2017-05-25 20:00
# UES_Northwest                1061
# UES_Siberia                     0
# UES_Center                   1204
# Name: 3476, dtype: object
# timestep         2017-05-25 21:00
# UES_Northwest                 757
# UES_Siberia                     0
# UES_Center                    810
# Name: 3477, dtype: object
# timestep         2017-05-25 22:00
# UES_Northwest                 432
# UES_Siberia                     0
# UES_Center                    543
# Name: 3478, dtype: object
# timestep         2017-05-25 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 3479, dtype: object
# timestep         2017-05-26 18:00
# UES_Northwest                 854
# UES_Siberia                     0
# UES_Center                   1102
# Name: 3498, dtype: object
# timestep         2017-05-26 20:00
# UES_Northwest                1201
# UES_Siberia                     0
# UES_Center                   1357
# Name: 3500, dtype: object
# timestep         2017-05-26 21:00
# UES_Northwest                1353
# UES_Siberia                     0
# UES_Center                   1477
# Name: 3501, dtype: object
# timestep         2017-05-26 22:00
# UES_Northwest                 636
# UES_Siberia                     0
# UES_Center                    781
# Name: 3502, dtype: object
# timestep         2017-05-26 23:00
# UES_Northwest                  14
# UES_Siberia                     0
# UES_Center                     18
# Name: 3503, dtype: object
# timestep         2017-05-29 01:00
# UES_Northwest                 421
# UES_Siberia                     0
# UES_Center                    530
# Name: 3553, dtype: object
# timestep         2017-05-29 19:00
# UES_Northwest                1214
# UES_Siberia                     0
# UES_Center                   1390
# Name: 3571, dtype: object
# timestep         2017-05-29 20:00
# UES_Northwest                1258
# UES_Siberia                     0
# UES_Center                   1446
# Name: 3572, dtype: object
# timestep         2017-05-29 21:00
# UES_Northwest                1148
# UES_Siberia                     0
# UES_Center                   1273
# Name: 3573, dtype: object
# timestep         2017-05-29 22:00
# UES_Northwest                 839
# UES_Siberia                     0
# UES_Center                    892
# Name: 3574, dtype: object
# timestep         2017-05-29 23:00
# UES_Northwest                 467
# UES_Siberia                     0
# UES_Center                    494
# Name: 3575, dtype: object
# timestep         2017-05-30 19:00
# UES_Northwest                 882
# UES_Siberia                     0
# UES_Center                   1010
# Name: 3595, dtype: object
# timestep         2017-05-30 20:00
# UES_Northwest                1113
# UES_Siberia                     0
# UES_Center                   1269
# Name: 3596, dtype: object
# timestep         2017-05-30 21:00
# UES_Northwest                1259
# UES_Siberia                     0
# UES_Center                   1396
# Name: 3597, dtype: object
# timestep         2017-05-30 22:00
# UES_Northwest                 787
# UES_Siberia                     0
# UES_Center                    828
# Name: 3598, dtype: object
# timestep         2017-05-30 23:00
# UES_Northwest                 550
# UES_Siberia                     0
# UES_Center                    570
# Name: 3599, dtype: object
# timestep         2017-05-31 00:00
# UES_Northwest                 720
# UES_Siberia                     0
# UES_Center                    754
# Name: 3600, dtype: object
# timestep         2017-05-31 01:00
# UES_Northwest                 473
# UES_Siberia                     0
# UES_Center                    503
# Name: 3601, dtype: object
# timestep         2017-05-31 20:00
# UES_Northwest                1336
# UES_Siberia                     0
# UES_Center                   1521
# Name: 3620, dtype: object
# timestep         2017-05-31 21:00
# UES_Northwest                1303
# UES_Siberia                     0
# UES_Center                   1614
# Name: 3621, dtype: object
# timestep         2017-05-31 22:00
# UES_Northwest                1220
# UES_Siberia                     0
# UES_Center                   1304
# Name: 3622, dtype: object
# timestep         2017-05-31 23:00
# UES_Northwest                 760
# UES_Siberia                     0
# UES_Center                    799
# Name: 3623, dtype: object
# timestep         2017-06-01 23:00
# UES_Northwest                 749
# UES_Siberia                     0
# UES_Center                    788
# Name: 3647, dtype: object
# timestep         2017-06-02 00:00
# UES_Northwest                 790
# UES_Siberia                     0
# UES_Center                    839
# Name: 3648, dtype: object
# timestep         2017-06-02 01:00
# UES_Northwest                 491
# UES_Siberia                     0
# UES_Center                    525
# Name: 3649, dtype: object
# timestep         2017-06-02 02:00
# UES_Northwest                 482
# UES_Siberia                     0
# UES_Center                    520
# Name: 3650, dtype: object
# timestep         2017-06-02 03:00
# UES_Northwest                 293
# UES_Siberia                     0
# UES_Center                    317
# Name: 3651, dtype: object
# timestep         2017-06-02 04:00
# UES_Northwest                 595
# UES_Siberia                     0
# UES_Center                    645
# Name: 3652, dtype: object
# timestep         2017-06-02 05:00
# UES_Northwest                 768
# UES_Siberia                     0
# UES_Center                    834
# Name: 3653, dtype: object
# timestep         2017-06-02 19:00
# UES_Northwest                1284
# UES_Siberia                     0
# UES_Center                   1454
# Name: 3667, dtype: object
# timestep         2017-06-02 20:00
# UES_Northwest                1331
# UES_Siberia                     0
# UES_Center                   1513
# Name: 3668, dtype: object
# timestep         2017-06-04 23:00
# UES_Northwest                 811
# UES_Siberia                     0
# UES_Center                    897
# Name: 3719, dtype: object
# timestep         2017-06-05 19:00
# UES_Northwest                1040
# UES_Siberia                     0
# UES_Center                   1468
# Name: 3739, dtype: object
# timestep         2017-06-05 20:00
# UES_Northwest                1053
# UES_Siberia                     0
# UES_Center                   1485
# Name: 3740, dtype: object
# timestep         2017-06-05 21:00
# UES_Northwest                1064
# UES_Siberia                     0
# UES_Center                   1471
# Name: 3741, dtype: object
# timestep         2017-06-05 22:00
# UES_Northwest                 907
# UES_Siberia                     0
# UES_Center                   1219
# Name: 3742, dtype: object
# timestep         2017-06-05 23:00
# UES_Northwest                 818
# UES_Siberia                     0
# UES_Center                   1106
# Name: 3743, dtype: object
# timestep         2017-06-06 19:00
# UES_Northwest                 793
# UES_Siberia                     0
# UES_Center                   1116
# Name: 3763, dtype: object
# timestep         2017-06-06 20:00
# UES_Northwest                 974
# UES_Siberia                     0
# UES_Center                   1372
# Name: 3764, dtype: object
# timestep         2017-06-06 21:00
# UES_Northwest                1043
# UES_Siberia                     0
# UES_Center                   1468
# Name: 3765, dtype: object
# timestep         2017-06-06 22:00
# UES_Northwest                 605
# UES_Siberia                     0
# UES_Center                    795
# Name: 3766, dtype: object
# timestep         2017-06-06 23:00
# UES_Northwest                 699
# UES_Siberia                     0
# UES_Center                    851
# Name: 3767, dtype: object
# timestep         2017-06-07 00:00
# UES_Northwest                 656
# UES_Siberia                     0
# UES_Center                    842
# Name: 3768, dtype: object
# timestep         2017-06-07 01:00
# UES_Northwest                 670
# UES_Siberia                     0
# UES_Center                    698
# Name: 3769, dtype: object
# timestep         2017-06-07 18:00
# UES_Northwest                 680
# UES_Siberia                     0
# UES_Center                    779
# Name: 3786, dtype: object
# timestep         2017-06-07 19:00
# UES_Northwest                1036
# UES_Siberia                     0
# UES_Center                   1168
# Name: 3787, dtype: object
# timestep         2017-06-07 20:00
# UES_Northwest                 857
# UES_Siberia                     0
# UES_Center                   1249
# Name: 3788, dtype: object
# timestep         2017-06-07 21:00
# UES_Northwest                1202
# UES_Siberia                     0
# UES_Center                   1519
# Name: 3789, dtype: object
# timestep         2017-06-07 22:00
# UES_Northwest                 617
# UES_Siberia                     0
# UES_Center                    943
# Name: 3790, dtype: object
# timestep         2017-06-07 23:00
# UES_Northwest                 317
# UES_Siberia                     0
# UES_Center                    604
# Name: 3791, dtype: object
# timestep         2017-06-08 00:00
# UES_Northwest                 475
# UES_Siberia                     0
# UES_Center                    803
# Name: 3792, dtype: object
# timestep         2017-06-08 19:00
# UES_Northwest                 869
# UES_Siberia                     0
# UES_Center                   1256
# Name: 3811, dtype: object
# timestep         2017-06-08 21:00
# UES_Northwest                1221
# UES_Siberia                     0
# UES_Center                   1539
# Name: 3813, dtype: object
# timestep         2017-06-08 22:00
# UES_Northwest                 553
# UES_Siberia                     0
# UES_Center                   1091
# Name: 3814, dtype: object
# timestep         2017-06-08 23:00
# UES_Northwest                 415
# UES_Siberia                     0
# UES_Center                    543
# Name: 3815, dtype: object
# timestep         2017-06-22 21:00
# UES_Northwest                1042
# UES_Siberia                     0
# UES_Center                   1424
# Name: 4149, dtype: object
# timestep         2017-06-22 23:00
# UES_Northwest                 578
# UES_Siberia                     0
# UES_Center                    754
# Name: 4151, dtype: object
# timestep         2017-06-24 23:00
# UES_Northwest                 380
# UES_Siberia                     0
# UES_Center                    540
# Name: 4199, dtype: object
# timestep         2017-06-29 00:00
# UES_Northwest                 566
# UES_Siberia                     0
# UES_Center                    645
# Name: 4296, dtype: object
# timestep         2017-06-29 01:00
# UES_Northwest                 477
# UES_Siberia                     0
# UES_Center                    635
# Name: 4297, dtype: object
# timestep         2017-06-29 02:00
# UES_Northwest                 415
# UES_Siberia                     0
# UES_Center                    557
# Name: 4298, dtype: object
# timestep         2017-06-30 00:00
# UES_Northwest                 428
# UES_Siberia                     0
# UES_Center                    571
# Name: 4320, dtype: object
# timestep         2017-07-01 01:00
# UES_Northwest                 666
# UES_Siberia                     0
# UES_Center                    882
# Name: 4345, dtype: object
# timestep         2017-07-01 03:00
# UES_Northwest                 540
# UES_Siberia                     0
# UES_Center                    728
# Name: 4347, dtype: object
# timestep         2017-07-02 00:00
# UES_Northwest                 665
# UES_Siberia                     0
# UES_Center                    879
# Name: 4368, dtype: object
# timestep         2017-07-02 23:00
# UES_Northwest                 463
# UES_Siberia                     0
# UES_Center                    622
# Name: 4391, dtype: object
# timestep         2017-07-03 00:00
# UES_Northwest                 402
# UES_Siberia                     0
# UES_Center                    571
# Name: 4392, dtype: object
# timestep         2017-07-03 01:00
# UES_Northwest                   2
# UES_Siberia                     0
# UES_Center                      3
# Name: 4393, dtype: object
# timestep         2017-07-03 02:00
# UES_Northwest                  40
# UES_Siberia                     0
# UES_Center                     49
# Name: 4394, dtype: object
# timestep         2017-07-03 20:00
# UES_Northwest                1018
# UES_Siberia                     0
# UES_Center                   1459
# Name: 4412, dtype: object
# timestep         2017-07-03 21:00
# UES_Northwest                 978
# UES_Siberia                     0
# UES_Center                   1397
# Name: 4413, dtype: object
# timestep         2017-07-03 22:00
# UES_Northwest                 758
# UES_Siberia                     0
# UES_Center                    947
# Name: 4414, dtype: object
# timestep         2017-07-04 01:00
# UES_Northwest                   2
# UES_Siberia                     0
# UES_Center                      2
# Name: 4417, dtype: object
# timestep         2017-07-04 23:00
# UES_Northwest                 406
# UES_Siberia                     0
# UES_Center                    551
# Name: 4439, dtype: object
# timestep         2017-07-05 01:00
# UES_Northwest                 341
# UES_Siberia                     0
# UES_Center                    475
# Name: 4441, dtype: object
# timestep         2017-07-05 02:00
# UES_Northwest                   5
# UES_Siberia                     0
# UES_Center                      7
# Name: 4442, dtype: object
# timestep         2017-07-05 11:00
# UES_Northwest                 622
# UES_Siberia                     0
# UES_Center                    889
# Name: 4451, dtype: object
# timestep         2017-07-05 17:00
# UES_Northwest                 619
# UES_Siberia                     0
# UES_Center                    889
# Name: 4457, dtype: object
# timestep         2017-07-05 21:00
# UES_Northwest                1104
# UES_Siberia                     0
# UES_Center                   1310
# Name: 4461, dtype: object
# timestep         2017-07-05 22:00
# UES_Northwest                 618
# UES_Siberia                     0
# UES_Center                    841
# Name: 4462, dtype: object
# timestep         2017-07-05 23:00
# UES_Northwest                 440
# UES_Siberia                     0
# UES_Center                    490
# Name: 4463, dtype: object
# timestep         2017-07-06 21:00
# UES_Northwest                 855
# UES_Siberia                     0
# UES_Center                   1234
# Name: 4485, dtype: object
# timestep         2017-07-06 23:00
# UES_Northwest                 487
# UES_Siberia                     0
# UES_Center                    296
# Name: 4487, dtype: object
# timestep         2017-07-07 23:00
# UES_Northwest                 654
# UES_Siberia                     0
# UES_Center                    582
# Name: 4511, dtype: object
# timestep         2017-07-09 22:00
# UES_Northwest                 742
# UES_Siberia                     0
# UES_Center                    964
# Name: 4558, dtype: object
# timestep         2017-07-10 22:00
# UES_Northwest                 733
# UES_Siberia                     0
# UES_Center                    878
# Name: 4582, dtype: object
# timestep         2017-07-10 23:00
# UES_Northwest                 447
# UES_Siberia                     0
# UES_Center                    550
# Name: 4583, dtype: object
# timestep         2017-07-12 00:00
# UES_Northwest                 357
# UES_Siberia                     0
# UES_Center                    543
# Name: 4608, dtype: object
# timestep         2017-07-12 01:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4609, dtype: object
# timestep         2017-07-12 02:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4610, dtype: object
# timestep         2017-07-12 22:00
# UES_Northwest                 864
# UES_Siberia                     0
# UES_Center                   1047
# Name: 4630, dtype: object
# timestep         2017-07-12 23:00
# UES_Northwest                 418
# UES_Siberia                     0
# UES_Center                    496
# Name: 4631, dtype: object
# timestep         2017-07-13 00:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4632, dtype: object
# timestep         2017-07-13 01:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4633, dtype: object
# timestep         2017-07-13 02:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4634, dtype: object
# timestep         2017-07-13 03:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 4635, dtype: object
# timestep         2017-07-18 01:00
# UES_Northwest                  33
# UES_Siberia                     0
# UES_Center                     48
# Name: 4753, dtype: object
# timestep         2017-07-18 21:00
# UES_Northwest                 980
# UES_Siberia                     0
# UES_Center                   1448
# Name: 4773, dtype: object
# timestep         2017-08-02 21:00
# UES_Northwest                 967
# UES_Siberia                     0
# UES_Center                   1528
# Name: 5133, dtype: object
# timestep         2017-08-03 01:00
# UES_Northwest                 357
# UES_Siberia                     0
# UES_Center                    545
# Name: 5137, dtype: object
# timestep         2017-08-08 00:00
# UES_Northwest                  37
# UES_Siberia                     0
# UES_Center                     53
# Name: 5256, dtype: object
# timestep         2017-08-08 23:00
# UES_Northwest                 490
# UES_Siberia                     0
# UES_Center                    555
# Name: 5279, dtype: object
# timestep         2017-08-09 22:00
# UES_Northwest                 690
# UES_Siberia                     0
# UES_Center                    907
# Name: 5302, dtype: object
# timestep         2017-08-10 00:00
# UES_Northwest                   3
# UES_Siberia                     0
# UES_Center                      3
# Name: 5304, dtype: object
# timestep         2017-08-10 01:00
# UES_Northwest                  50
# UES_Siberia                     0
# UES_Center                     75
# Name: 5305, dtype: object
# timestep         2017-08-10 02:00
# UES_Northwest                  14
# UES_Siberia                     0
# UES_Center                     20
# Name: 5306, dtype: object
# timestep         2017-08-10 03:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 5307, dtype: object
# timestep         2017-08-10 20:00
# UES_Northwest                1057
# UES_Siberia                     0
# UES_Center                   1474
# Name: 5324, dtype: object
# timestep         2017-08-11 23:00
# UES_Northwest                 556
# UES_Siberia                     0
# UES_Center                    632
# Name: 5351, dtype: object
# timestep         2017-08-12 22:00
# UES_Northwest                 871
# UES_Siberia                     0
# UES_Center                    980
# Name: 5374, dtype: object
# timestep         2017-08-15 23:00
# UES_Northwest                 547
# UES_Siberia                     0
# UES_Center                    825
# Name: 5447, dtype: object
# timestep         2017-08-25 23:00
# UES_Northwest                 933
# UES_Siberia                     0
# UES_Center                   1114
# Name: 5687, dtype: object
# timestep         2017-10-02 21:00
# UES_Northwest                 966
# UES_Siberia                     0
# UES_Center                   1409
# Name: 6597, dtype: object
# timestep         2017-10-02 22:00
# UES_Northwest                 720
# UES_Siberia                     0
# UES_Center                   1110
# Name: 6598, dtype: object
# timestep         2017-10-09 21:00
# UES_Northwest                 803
# UES_Siberia                     0
# UES_Center                   1141
# Name: 6765, dtype: object
# timestep         2017-10-09 22:00
# UES_Northwest                 590
# UES_Siberia                     0
# UES_Center                    823
# Name: 6766, dtype: object
# timestep         2017-10-09 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      1
# Name: 6767, dtype: object
# timestep         2017-10-12 23:00
# UES_Northwest                 580
# UES_Siberia                     0
# UES_Center                    656
# Name: 6839, dtype: object
# timestep         2017-10-17 23:00
# UES_Northwest                 731
# UES_Siberia                     0
# UES_Center                    835
# Name: 6959, dtype: object
# timestep         2017-10-18 20:00
# UES_Northwest                1113
# UES_Siberia                     0
# UES_Center                   1493
# Name: 6980, dtype: object
# timestep         2017-10-18 21:00
# UES_Northwest                1054
# UES_Siberia                     0
# UES_Center                   1379
# Name: 6981, dtype: object
# timestep         2017-10-18 22:00
# UES_Northwest                 693
# UES_Siberia                     0
# UES_Center                    914
# Name: 6982, dtype: object
# timestep         2017-10-18 23:00
# UES_Northwest                 693
# UES_Siberia                     0
# UES_Center                    927
# Name: 6983, dtype: object
# timestep         2017-10-20 22:00
# UES_Northwest                 707
# UES_Siberia                     0
# UES_Center                    948
# Name: 7030, dtype: object
# timestep         2017-10-21 23:00
# UES_Northwest                 654
# UES_Siberia                     0
# UES_Center                    920
# Name: 7055, dtype: object
# timestep         2017-10-22 23:00
# UES_Northwest                 850
# UES_Siberia                     0
# UES_Center                   1183
# Name: 7079, dtype: object
# timestep         2017-10-23 22:00
# UES_Northwest                 725
# UES_Siberia                     0
# UES_Center                    988
# Name: 7102, dtype: object
# timestep         2017-10-25 23:00
# UES_Northwest                 792
# UES_Siberia                     0
# UES_Center                    912
# Name: 7151, dtype: object
# timestep         2017-10-29 21:00
# UES_Northwest                 646
# UES_Siberia                     0
# UES_Center                    881
# Name: 7245, dtype: object
# timestep         2017-10-29 23:00
# UES_Northwest                 500
# UES_Siberia                     0
# UES_Center                    697
# Name: 7247, dtype: object
# timestep         2017-10-30 22:00
# UES_Northwest                  22
# UES_Siberia                     0
# UES_Center                     26
# Name: 7270, dtype: object
# timestep         2017-10-30 23:00
# UES_Northwest                  15
# UES_Siberia                     0
# UES_Center                     18
# Name: 7271, dtype: object
# timestep         2017-11-01 23:00
# UES_Northwest                 410
# UES_Siberia                     0
# UES_Center                    560
# Name: 7319, dtype: object
# timestep         2017-11-03 22:00
# UES_Northwest                 736
# UES_Siberia                     0
# UES_Center                    885
# Name: 7366, dtype: object
# timestep         2017-11-03 23:00
# UES_Northwest                 305
# UES_Siberia                     0
# UES_Center                    421
# Name: 7367, dtype: object
# timestep         2017-11-09 22:00
# UES_Northwest                 785
# UES_Siberia                     0
# UES_Center                    888
# Name: 7510, dtype: object
# timestep         2017-11-09 23:00
# UES_Northwest                 754
# UES_Siberia                     0
# UES_Center                    861
# Name: 7511, dtype: object
# timestep         2017-11-26 22:00
# UES_Northwest                 771
# UES_Siberia                     0
# UES_Center                    897
# Name: 7918, dtype: object
# timestep         2017-12-04 22:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      2
# Name: 8110, dtype: object
# timestep         2017-12-11 23:00
# UES_Northwest                  26
# UES_Siberia                     0
# UES_Center                     29
# Name: 8279, dtype: object
# timestep         2017-12-18 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      5
# Name: 8447, dtype: object
# timestep         2017-12-23 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      6
# Name: 8567, dtype: object
# timestep         2018-01-16 22:00
# UES_Northwest                 793
# UES_Siberia                     0
# UES_Center                   1050
# Name: 9142, dtype: object
# timestep         2018-01-16 23:00
# UES_Northwest                 867
# UES_Siberia                     0
# UES_Center                    989
# Name: 9143, dtype: object
# timestep         2018-03-28 21:00
# UES_Northwest                1030
# UES_Siberia                     0
# UES_Center                   1185
# Name: 10845, dtype: object
# timestep         2018-04-09 21:00
# UES_Northwest                 920
# UES_Siberia                     0
# UES_Center                   1026
# Name: 11133, dtype: object
# timestep         2018-04-09 22:00
# UES_Northwest                 749
# UES_Siberia                     0
# UES_Center                    687
# Name: 11134, dtype: object
# timestep         2018-04-20 23:00
# UES_Northwest                 716
# UES_Siberia                     0
# UES_Center                    806
# Name: 11399, dtype: object
# timestep         2018-04-22 21:00
# UES_Northwest                1161
# UES_Siberia                     0
# UES_Center                   1380
# Name: 11445, dtype: object
# timestep         2018-04-22 23:00
# UES_Northwest                 896
# UES_Siberia                     0
# UES_Center                   1058
# Name: 11447, dtype: object
# timestep         2018-04-23 19:00
# UES_Northwest                1422
# UES_Siberia                     0
# UES_Center                   1671
# Name: 11467, dtype: object
# timestep         2018-04-24 21:00
# UES_Northwest                1201
# UES_Siberia                     0
# UES_Center                   1373
# Name: 11493, dtype: object
# timestep         2018-04-25 20:00
# UES_Northwest                1296
# UES_Siberia                     0
# UES_Center                   1527
# Name: 11516, dtype: object
# timestep         2018-04-26 09:00
# UES_Northwest                1440
# UES_Siberia                     0
# UES_Center                   1723
# Name: 11529, dtype: object
# timestep         2018-04-26 10:00
# UES_Northwest                1449
# UES_Siberia                     0
# UES_Center                   1735
# Name: 11530, dtype: object
# timestep         2018-04-26 12:00
# UES_Northwest                1487
# UES_Siberia                     0
# UES_Center                   1789
# Name: 11532, dtype: object
# timestep         2018-04-26 13:00
# UES_Northwest                1553
# UES_Siberia                     0
# UES_Center                   1867
# Name: 11533, dtype: object
# timestep         2018-04-26 21:00
# UES_Northwest                1044
# UES_Siberia                     0
# UES_Center                   1351
# Name: 11541, dtype: object
# timestep         2018-04-26 22:00
# UES_Northwest                 751
# UES_Siberia                     0
# UES_Center                    923
# Name: 11542, dtype: object
# timestep         2018-04-26 23:00
# UES_Northwest                  49
# UES_Siberia                     0
# UES_Center                      3
# Name: 11543, dtype: object
# timestep         2018-05-01 22:00
# UES_Northwest                 948
# UES_Siberia                     0
# UES_Center                   1166
# Name: 11662, dtype: object
# timestep         2018-05-03 21:00
# ...
# timestep         2018-10-16 22:00
# UES_Northwest                 938
# UES_Siberia                     0
# UES_Center                   1024
# Name: 15694, dtype: object
# timestep         2018-10-16 23:00
# UES_Northwest                 889
# UES_Siberia                     0
# UES_Center                    979
# Name: 15695, dtype: object
# timestep         2018-10-18 22:00
# UES_Northwest                1004
# UES_Siberia                     0
# UES_Center                   1115
# Name: 15742, dtype: object
# timestep         2018-10-24 22:00
# UES_Northwest                 754
# UES_Siberia                     0
# UES_Center                    854
# Name: 15886, dtype: object
# timestep         2018-10-28 23:00
# UES_Northwest                 737
# UES_Siberia                     0
# UES_Center                    839
# Name: 15983, dtype: object
# timestep         2018-10-30 23:00
# UES_Northwest                 941
# UES_Siberia                     0
# UES_Center                   1054
# Name: 16031, dtype: object
# timestep         2018-11-01 22:00
# UES_Northwest                 985
# UES_Siberia                     0
# UES_Center                   1026
# Name: 16078, dtype: object
# timestep         2018-11-02 01:00
# UES_Northwest                 734
# UES_Siberia                     0
# UES_Center                    815
# Name: 16081, dtype: object
# timestep         2018-11-07 21:00
# UES_Northwest                 981
# UES_Siberia                     0
# UES_Center                   1174
# Name: 16221, dtype: object
# timestep         2018-11-11 20:00
# UES_Northwest                1007
# UES_Siberia                     0
# UES_Center                   1168
# Name: 16316, dtype: object
# timestep         2018-11-11 21:00
# UES_Northwest                 998
# UES_Siberia                     0
# UES_Center                   1158
# Name: 16317, dtype: object
# timestep         2018-11-11 22:00
# UES_Northwest                 763
# UES_Siberia                     0
# UES_Center                   1008
# Name: 16318, dtype: object
# timestep         2018-11-11 23:00
# UES_Northwest                 821
# UES_Siberia                     0
# UES_Center                    934
# Name: 16319, dtype: object
# timestep         2018-11-12 23:00
# UES_Northwest                 648
# UES_Siberia                     0
# UES_Center                    823
# Name: 16343, dtype: object
# timestep         2018-11-16 22:00
# UES_Northwest                1043
# UES_Siberia                     0
# UES_Center                   1242
# Name: 16438, dtype: object
# timestep         2018-11-17 19:00
# UES_Northwest                1282
# UES_Siberia                     0
# UES_Center                   1570
# Name: 16459, dtype: object
# timestep         2018-11-17 22:00
# UES_Northwest                 945
# UES_Siberia                     0
# UES_Center                   1133
# Name: 16462, dtype: object
# timestep         2018-11-21 23:00
# UES_Northwest                 513
# UES_Siberia                     0
# UES_Center                    582
# Name: 16559, dtype: object
# timestep         2018-11-22 22:00
# UES_Northwest                   7
# UES_Siberia                     0
# UES_Center                      5
# Name: 16582, dtype: object
# timestep         2018-11-25 23:00
# UES_Northwest                  49
# UES_Siberia                     0
# UES_Center                      1
# Name: 16655, dtype: object
# timestep         2018-12-02 22:00
# UES_Northwest                 630
# UES_Siberia                     0
# UES_Center                    719
# Name: 16822, dtype: object
# timestep         2018-12-02 23:00
# UES_Northwest                  19
# UES_Siberia                     0
# UES_Center                     20
# Name: 16823, dtype: object
# timestep         2018-12-04 21:00
# UES_Northwest                 827
# UES_Siberia                     0
# UES_Center                    947
# Name: 16869, dtype: object
# timestep         2018-12-04 22:00
# UES_Northwest                 726
# UES_Siberia                     0
# UES_Center                    826
# Name: 16870, dtype: object
# timestep         2018-12-04 23:00
# UES_Northwest                 323
# UES_Siberia                     0
# UES_Center                    364
# Name: 16871, dtype: object
# timestep         2018-12-14 22:00
# UES_Northwest                 933
# UES_Siberia                     0
# UES_Center                   1010
# Name: 17110, dtype: object
# timestep         2018-12-17 21:00
# UES_Northwest                 929
# UES_Siberia                     0
# UES_Center                   1004
# Name: 17181, dtype: object
# timestep         2018-12-18 23:00
# UES_Northwest                 757
# UES_Siberia                     0
# UES_Center                    818
# Name: 17207, dtype: object
# timestep         2018-12-20 23:00
# UES_Northwest                 774
# UES_Siberia                     0
# UES_Center                    828
# Name: 17255, dtype: object
# timestep         2018-12-29 23:00
# UES_Northwest                   9
# UES_Siberia                     0
# UES_Center                      7
# Name: 17471, dtype: object
# timestep         2018-12-31 23:00
# UES_Northwest                   5
# UES_Siberia                     0
# UES_Center                      3
# Name: 17519, dtype: object
# timestep         2019-01-06 23:00
# UES_Northwest                 407
# UES_Siberia                     0
# UES_Center                    464
# Name: 17663, dtype: object
# timestep         2019-01-10 23:00
# UES_Northwest                 548
# UES_Siberia                     0
# UES_Center                    617
# Name: 17759, dtype: object
# timestep         2019-01-14 23:00
# UES_Northwest                 499
# UES_Siberia                     0
# UES_Center                    556
# Name: 17855, dtype: object
# timestep         2019-01-20 23:00
# UES_Northwest                  16
# UES_Siberia                     0
# UES_Center                     14
# Name: 17999, dtype: object
# timestep         2019-01-21 23:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      1
# Name: 18023, dtype: object
# timestep         2019-01-22 22:00
# UES_Northwest                 932
# UES_Siberia                     0
# UES_Center                    938
# Name: 18046, dtype: object
# timestep         2019-01-22 23:00
# UES_Northwest                 876
# UES_Siberia                     0
# UES_Center                    882
# Name: 18047, dtype: object
# timestep         2019-01-23 23:00
# UES_Northwest                 704
# UES_Siberia                     0
# UES_Center                    704
# Name: 18071, dtype: object
# timestep         2019-01-24 23:00
# UES_Northwest                 710
# UES_Siberia                     0
# UES_Center                    715
# Name: 18095, dtype: object
# timestep         2019-01-28 23:00
# UES_Northwest                 351
# UES_Siberia                     0
# UES_Center                     82
# Name: 18191, dtype: object
# timestep         2019-01-29 23:00
# UES_Northwest                 690
# UES_Siberia                     0
# UES_Center                    607
# Name: 18215, dtype: object
# timestep         2019-01-30 23:00
# UES_Northwest                 305
# UES_Siberia                     0
# UES_Center                     16
# Name: 18239, dtype: object
# timestep         2019-02-07 23:00
# UES_Northwest                 265
# UES_Siberia                     0
# UES_Center                    281
# Name: 18431, dtype: object
# timestep         2019-02-08 23:00
# UES_Northwest                 267
# UES_Siberia                     0
# UES_Center                    283
# Name: 18455, dtype: object
# timestep         2019-02-10 20:00
# UES_Northwest                1216
# UES_Siberia                     0
# UES_Center                   1289
# Name: 18500, dtype: object
# timestep         2019-02-10 22:00
# UES_Northwest                 692
# UES_Siberia                     0
# UES_Center                    748
# Name: 18502, dtype: object
# timestep         2019-04-06 23:00
# UES_Northwest                1117
# UES_Siberia                     0
# UES_Center                   1184
# Name: 19823, dtype: object
# timestep         2019-04-14 22:00
# UES_Northwest                 965
# UES_Siberia                     0
# UES_Center                    986
# Name: 20014, dtype: object
# timestep         2019-04-23 23:00
# UES_Northwest                1867
# UES_Siberia                     0
# UES_Center                   1974
# Name: 20231, dtype: object
# timestep         2019-05-06 23:00
# UES_Northwest                 858
# UES_Siberia                     0
# UES_Center                    916
# Name: 20543, dtype: object
# timestep         2019-06-29 23:00
# UES_Northwest                1298
# UES_Siberia                     0
# UES_Center                   1725
# Name: 21839, dtype: object
# timestep         2019-06-30 23:00
# UES_Northwest                 637
# UES_Siberia                     0
# UES_Center                    739
# Name: 21863, dtype: object
# timestep         2019-07-02 23:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      3
# Name: 21911, dtype: object
# timestep         2019-07-17 20:00
# UES_Northwest                1275
# UES_Siberia                     0
# UES_Center                   1550
# Name: 22268, dtype: object
# timestep         2019-07-19 21:00
# UES_Northwest                1407
# UES_Siberia                     0
# UES_Center                   1618
# Name: 22317, dtype: object
# timestep         2019-07-19 23:00
# UES_Northwest                 715
# UES_Siberia                     0
# UES_Center                    955
# Name: 22319, dtype: object
# timestep         2019-07-20 22:00
# UES_Northwest                1004
# UES_Siberia                     0
# UES_Center                   1363
# Name: 22342, dtype: object
# timestep         2019-07-23 00:00
# UES_Northwest                 605
# UES_Siberia                     0
# UES_Center                    810
# Name: 22392, dtype: object
# timestep         2019-07-30 04:00
# UES_Northwest                   4
# UES_Siberia                     0
# UES_Center                      0
# Name: 22564, dtype: object
# timestep         2019-08-03 21:00
# UES_Northwest                1353
# UES_Siberia                     0
# UES_Center                   1497
# Name: 22677, dtype: object
# timestep         2019-08-06 21:00
# UES_Northwest                 189
# UES_Siberia                     0
# UES_Center                   1509
# Name: 22749, dtype: object
# timestep         2019-08-06 22:00
# UES_Northwest                 150
# UES_Siberia                     0
# UES_Center                   1305
# Name: 22750, dtype: object
# timestep         2019-08-08 23:00
# UES_Northwest                 654
# UES_Siberia                     0
# UES_Center                    837
# Name: 22799, dtype: object
# timestep         2019-08-21 22:00
# UES_Northwest                1105
# UES_Siberia                     0
# UES_Center                   1217
# Name: 23110, dtype: object
# timestep         2019-08-21 23:00
# UES_Northwest                 974
# UES_Siberia                     0
# UES_Center                   1063
# Name: 23111, dtype: object
# timestep         2019-08-23 22:00
# UES_Northwest                 999
# UES_Siberia                     0
# UES_Center                   1374
# Name: 23158, dtype: object
# timestep         2019-08-26 22:00
# UES_Northwest                 700
# UES_Siberia                     0
# UES_Center                    936
# Name: 23230, dtype: object
# timestep         2019-08-26 23:00
# UES_Northwest                  39
# UES_Siberia                     0
# UES_Center                     43
# Name: 23231, dtype: object
# timestep         2019-08-27 21:00
# UES_Northwest                1115
# UES_Siberia                     0
# UES_Center                   1186
# Name: 23253, dtype: object
# timestep         2019-08-29 21:00
# UES_Northwest                 782
# UES_Siberia                     0
# UES_Center                    945
# Name: 23301, dtype: object
# timestep         2019-09-03 22:00
# UES_Northwest                 884
# UES_Siberia                     0
# UES_Center                    933
# Name: 23422, dtype: object
# timestep         2019-09-03 23:00
# UES_Northwest                 760
# UES_Siberia                     0
# UES_Center                    805
# Name: 23423, dtype: object
# timestep         2019-09-15 21:00
# UES_Northwest                1005
# UES_Siberia                     0
# UES_Center                   1192
# Name: 23709, dtype: object
# timestep         2019-09-15 22:00
# UES_Northwest                 914
# UES_Siberia                     0
# UES_Center                   1049
# Name: 23710, dtype: object
# timestep         2019-09-17 21:00
# UES_Northwest                 932
# UES_Siberia                     0
# UES_Center                   1004
# Name: 23757, dtype: object
# timestep         2019-09-17 23:00
# UES_Northwest                 749
# UES_Siberia                     0
# UES_Center                    801
# Name: 23759, dtype: object
# timestep         2019-09-18 22:00
# UES_Northwest                 836
# UES_Siberia                     0
# UES_Center                    887
# Name: 23782, dtype: object
# timestep         2019-09-22 19:00
# UES_Northwest                1710
# UES_Siberia                     0
# UES_Center                   1807
# Name: 23875, dtype: object
# timestep         2019-09-22 20:00
# UES_Northwest                1655
# UES_Siberia                     0
# UES_Center                   1731
# Name: 23876, dtype: object
# timestep         2019-09-22 21:00
# UES_Northwest                1586
# UES_Siberia                     0
# UES_Center                   1602
# Name: 23877, dtype: object
# timestep         2019-09-22 22:00
# UES_Northwest                1252
# UES_Siberia                     0
# UES_Center                   1318
# Name: 23878, dtype: object
# timestep         2019-09-22 23:00
# UES_Northwest                1171
# UES_Siberia                     0
# UES_Center                   1231
# Name: 23879, dtype: object
# timestep         2019-09-23 21:00
# UES_Northwest                1451
# UES_Siberia                     0
# UES_Center                   1523
# Name: 23901, dtype: object
# timestep         2019-09-24 22:00
# UES_Northwest                1089
# UES_Siberia                     0
# UES_Center                   1112
# Name: 23926, dtype: object
# timestep         2019-09-25 20:00
# UES_Northwest                1126
# UES_Siberia                     0
# UES_Center                   1217
# Name: 23948, dtype: object
# timestep         2019-09-25 21:00
# UES_Northwest                1106
# UES_Siberia                     0
# UES_Center                   1150
# Name: 23949, dtype: object
# timestep         2019-09-25 22:00
# UES_Northwest                 980
# UES_Siberia                     0
# UES_Center                   1026
# Name: 23950, dtype: object
# timestep         2019-09-25 23:00
# UES_Northwest                 605
# UES_Siberia                     0
# UES_Center                    632
# Name: 23951, dtype: object
# timestep         2019-09-27 21:00
# UES_Northwest                 849
# UES_Siberia                     0
# UES_Center                   1016
# Name: 23997, dtype: object
# timestep         2019-09-27 22:00
# UES_Northwest                  77
# UES_Siberia                     0
# UES_Center                     94
# Name: 23998, dtype: object
# timestep         2019-09-27 23:00
# UES_Northwest                 544
# UES_Siberia                     0
# UES_Center                    653
# Name: 23999, dtype: object
# timestep         2019-09-28 21:00
# UES_Northwest                1125
# UES_Siberia                     0
# UES_Center                   1176
# Name: 24021, dtype: object
# timestep         2019-09-29 22:00
# UES_Northwest                 760
# UES_Siberia                     0
# UES_Center                    916
# Name: 24046, dtype: object
# timestep         2019-09-29 23:00
# UES_Northwest                  16
# UES_Siberia                     0
# UES_Center                     19
# Name: 24047, dtype: object
# timestep         2019-09-30 00:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      0
# Name: 24048, dtype: object
# timestep         2019-09-30 01:00
# UES_Northwest                   0
# UES_Siberia                     0
# UES_Center                      1
# Name: 24049, dtype: object
# timestep         2019-09-30 23:00
# UES_Northwest                   1
# UES_Siberia                     0
# UES_Center                      1
# Name: 24071, dtype: object

# %% [markdown]
# # OBSERVATION
#
# Observation of these values shows there are really low price values in all three regions, as low as 0 through 10.
# this could mean that only equivalent supply of electricity was provided, so I assume 0 means lack of electricity.
#
# There's no enough information on the data at the moment.

# %%
data_details(PZ_dayahead_price_volume)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45816 entries, 0 to 45815
# Data columns (total 5 columns):
# timestep           45816 non-null object
# consumption_eur    45816 non-null float64
# consumption_sib    45816 non-null float64
# price_eur          45816 non-null float64
# price_sib          45816 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 1.7+ MB
#            timestep  consumption_eur  consumption_sib  price_eur  price_sib
# 0  2006-09-01 00:00          62341.0          17916.0     275.22        0.0
# 1  2006-09-01 01:00          60625.0          17467.0       0.00        0.0
# 2  2006-09-01 02:00          59685.0          17161.0       0.00        0.0
# 3  2006-09-01 03:00          59500.0          17061.0       0.00        0.0
# 4  2006-09-01 04:00          60617.0          17074.0       0.00        0.0
# None
#        consumption_eur  consumption_sib     price_eur     price_sib
# count     45816.000000     45816.000000  45816.000000  45816.000000
# mean      82294.752037     22297.937294    730.232149    430.219400
# std       11046.135452      3035.991381    239.185651    167.183197
# min       57847.000000     15328.674800      0.000000      0.000000
# 25%       74157.500000     19697.000000    563.472500    365.077500
# 50%       81194.421875     22057.000000    708.590000    470.565000
# 75%       90337.886718     24788.054198    902.702500    533.752500
# max      111722.984400     30666.000000   2135.010000   1029.690000
# timestep           False
# consumption_eur    False
# consumption_sib    False
# price_eur          False
# price_sib          False
# dtype: bool
# (None, None, None, None)

# %%
data_details(UES_dayahead_price)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23952 entries, 0 to 23951
# Data columns (total 7 columns):
# timestep            23952 non-null object
# UES_Northwest       23952 non-null float64
# UES_Siberia         23952 non-null float64
# UES_Middle_Volga    23952 non-null float64
# UES_Urals           23952 non-null float64
# UES_Center          23952 non-null float64
# UES_South           23952 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 1.3+ MB
#            timestep  UES_Northwest  UES_Siberia  UES_Middle_Volga  UES_Urals  \
# 0  2017-01-01 00:00         964.67      1006.27           1032.80     953.23
# 1  2017-01-01 01:00         984.79      1003.79           1033.34     946.79
# 2  2017-01-01 02:00         962.54      1005.09           1029.51     944.35
# 3  2017-01-01 03:00         888.44      1002.38            976.34     906.15
# 4  2017-01-01 04:00         847.10      1002.58            945.28     894.08
#
#    UES_Center  UES_South
# 0     1050.17    1706.30
# 1     1051.15    1592.17
# 2     1039.84    1561.85
# 3      977.04    1534.37
# 4      938.27    1517.58
# None
#        UES_Northwest   UES_Siberia  UES_Middle_Volga     UES_Urals  \
# count   23952.000000  23952.000000      23952.000000  23952.000000
# mean     1154.931131    883.351245       1249.247091   1064.761827
# std       263.467122    152.045814        253.318931    161.532592
# min         0.000000      0.000000          0.000000      0.000000
# 25%       940.900000    812.127500       1032.942500    940.867500
# 50%      1206.395000    907.095000       1316.360000   1079.210000
# 75%      1354.622500    983.747500       1440.127500   1183.322500
# max      2488.860000   1229.400000       1822.970000   1518.630000
#
#          UES_Center     UES_South
# count  23952.000000  23952.000000
# mean    1318.963109   1495.635003
# std      291.512956    366.044747
# min        0.000000      0.000000
# 25%     1057.900000   1246.890000
# 50%     1400.825000   1605.135000
# 75%     1551.875000   1752.300000
# max     2687.760000   5039.830000
# timestep            False
# UES_Northwest       False
# UES_Siberia         False
# UES_Middle_Volga    False
# UES_Urals           False
# UES_Center          False
# UES_South           False
# dtype: bool
# (None, None, None, None)

# %% [markdown]
# ### Drop Zero Values

# %%
#write function to drop values below 50.0
#1. Convert timestep to datetime data type

def drop_vals(data):
    pd.to_datetime(data["timestep"])
    data.index = data["timestep"]
    data = data.drop("timestep", axis = 1)
    
    #2. replace all values between 0 & 50 with Nan
    
    data[(data >= 0.0) & (data <= 50.0)] = np.nan
    
    #3. drop all NaN values by row
    
    data = data.dropna(axis = 0)
    return data

# %%
UES_intraday_price = drop_vals(UES_intraday_price)
UES_intraday_price.head()
# Out:
#                   UES_Northwest  UES_Siberia  UES_Center
# timestep
# 2017-01-01 00:00          767.0        918.0       982.0
# 2017-01-01 01:00          675.0        889.0       848.0
# 2017-01-01 02:00          717.0        933.0       920.0
# 2017-01-01 03:00          683.0        947.0       885.0
# 2017-01-01 04:00          633.0        934.0       829.0

# %%
UES_intraday_price.describe()
# Out:
#        UES_Northwest   UES_Siberia    UES_Center
# count   23087.000000  23087.000000  23087.000000
# mean     1005.976047    824.779443   1229.181877
# std       299.950718    213.810783    333.598849
# min        54.000000     51.000000     53.000000
# 25%       805.000000    726.000000    982.000000
# 50%      1000.000000    865.000000   1236.000000
# 75%      1206.000000    969.000000   1483.000000
# max      6707.000000   1527.000000   6845.000000

# %%
UES_intraday_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23087 entries, 2017-01-01 00:00 to 2019-09-30 22:00
# Data columns (total 3 columns):
# UES_Northwest    23087 non-null float64
# UES_Siberia      23087 non-null float64
# UES_Center       23087 non-null float64
# dtypes: float64(3)
# memory usage: 1.3+ MB

# %%
PZ_dayahead_price_volume = drop_vals(PZ_dayahead_price_volume)
PZ_dayahead_price_volume.head()
# Out:
#                   consumption_eur  consumption_sib  price_eur  price_sib
# timestep
# 2006-09-03 21:00          70250.0          19531.0     514.92     276.99
# 2006-09-03 22:00          66733.0          19397.0     375.61     242.27
# 2006-09-05 16:00          72688.0          19364.0     503.68     255.55
# 2006-09-05 17:00          71822.0          19336.0     481.50     267.84
# 2006-09-05 18:00          71933.0          19410.0     475.10     272.73

# %%
PZ_dayahead_price_volume.describe()
# Out:
#        consumption_eur  consumption_sib     price_eur     price_sib
# count     41919.000000     41919.000000  41919.000000  41919.000000
# mean      82661.575606     22387.037535    757.891342    469.286830
# std       11141.969289      3073.767901    226.715960    111.910013
# min       58817.941400     15750.231440     50.260000     50.030000
# 25%       74369.933590     19724.709960    596.080000    412.605000
# 50%       81473.000000     22153.000000    736.930000    480.740000
# 75%       90961.500000     24976.005855    922.875000    540.305000
# max      111722.984400     30666.000000   2135.010000   1029.690000

# %%
PZ_dayahead_price_volume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41919 entries, 2006-09-03 21:00 to 2011-11-22 23:00
# Data columns (total 4 columns):
# consumption_eur    41919 non-null float64
# consumption_sib    41919 non-null float64
# price_eur          41919 non-null float64
# price_sib          41919 non-null float64
# dtypes: float64(4)
# memory usage: 2.8+ MB

# %%
UES_dayahead_price = drop_vals(UES_dayahead_price)
UES_dayahead_price.head()
# Out:
#                   UES_Northwest  UES_Siberia  UES_Middle_Volga  UES_Urals  \
# timestep
# 2017-01-01 00:00         964.67      1006.27           1032.80     953.23
# 2017-01-01 01:00         984.79      1003.79           1033.34     946.79
# 2017-01-01 02:00         962.54      1005.09           1029.51     944.35
# 2017-01-01 03:00         888.44      1002.38            976.34     906.15
# 2017-01-01 04:00         847.10      1002.58            945.28     894.08
#
#                   UES_Center  UES_South
# timestep
# 2017-01-01 00:00     1050.17    1706.30
# 2017-01-01 01:00     1051.15    1592.17
# 2017-01-01 02:00     1039.84    1561.85
# 2017-01-01 03:00      977.04    1534.37
# 2017-01-01 04:00      938.27    1517.58

# %%
UES_dayahead_price.describe()
# Out:
#        UES_Northwest   UES_Siberia  UES_Middle_Volga     UES_Urals  \
# count   23843.000000  23843.000000      23843.000000  23843.000000
# mean     1157.307762    885.032373       1251.548408   1066.361367
# std       259.627655    147.448137        249.676549    158.252028
# min        75.560000     50.440000         84.020000     92.960000
# 25%       943.300000    812.790000       1034.490000    942.005000
# 50%      1207.600000    907.340000       1317.340000   1080.480000
# 75%      1355.160000    983.900000       1440.765000   1183.890000
# max      2488.860000   1229.400000       1822.970000   1518.630000
#
#          UES_Center     UES_South
# count  23843.000000  23843.000000
# mean    1321.430512   1500.615355
# std      287.496510    356.953308
# min       77.680000     53.650000
# 25%     1059.695000   1253.980000
# 50%     1401.910000   1606.320000
# 75%     1552.630000   1752.620000
# max     2687.760000   5039.830000

# %%
UES_dayahead_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23843 entries, 2017-01-01 00:00 to 2019-09-25 23:00
# Data columns (total 6 columns):
# UES_Northwest       23843 non-null float64
# UES_Siberia         23843 non-null float64
# UES_Middle_Volga    23843 non-null float64
# UES_Urals           23843 non-null float64
# UES_Center          23843 non-null float64
# UES_South           23843 non-null float64
# dtypes: float64(6)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Moving On!

# %% [markdown]
# # Visualization

# %%
dayahead_price = PZ_dayahead_price_volume
dayahead_price.head()
# Out:
#                   consumption_eur  consumption_sib  price_eur  price_sib
# timestep
# 2006-09-03 21:00          70250.0          19531.0     514.92     276.99
# 2006-09-03 22:00          66733.0          19397.0     375.61     242.27
# 2006-09-05 16:00          72688.0          19364.0     503.68     255.55
# 2006-09-05 17:00          71822.0          19336.0     481.50     267.84
# 2006-09-05 18:00          71933.0          19410.0     475.10     272.73

# %%
"""dayahead_price["datetime"] = pd.to_datetime(dayahead_price["timestep"])
dayahead_price.drop("timestep", axis = 1, inplace = True)
dayahead_price.set_index(["datetime"], drop = True, inplace = True)
dayahead_price.head()
# Out:
#                      consumption_eur  consumption_sib  price_eur  price_sib
# datetime
# 2006-09-01 00:00:00          62341.0          17916.0     275.22        0.0
# 2006-09-01 01:00:00          60625.0          17467.0       0.00        0.0
# 2006-09-01 02:00:00          59685.0          17161.0       0.00        0.0
# 2006-09-01 03:00:00          59500.0          17061.0       0.00        0.0
# 2006-09-01 04:00:00          60617.0          17074.0       0.00        0.0

# %%
plt.figure(figsize = (15,15))

ax1 = plt.subplot(4, 1, 1)
dayahead_price['consumption_eur'].plot()
ax1.set_ylabel("consumption_eur")

ax2 = plt.subplot(4, 1, 2)
dayahead_price['consumption_sib'].plot()
ax2.set_ylabel("consumption_sib")

ax3 = plt.subplot(4, 1, 3)
dayahead_price['price_eur'].plot()
ax3.set_ylabel("price_eur")

ax4 = plt.subplot(4, 1, 4)
dayahead_price['price_sib'].plot()
ax4.set_ylabel("price_sib")
# Out:
# Text(0, 0.5, 'price_sib')

# %%
UES_dayahead_price.head()
# Out:
#                   UES_Northwest  UES_Siberia  UES_Middle_Volga  UES_Urals  \
# timestep
# 2017-01-01 00:00         964.67      1006.27           1032.80     953.23
# 2017-01-01 01:00         984.79      1003.79           1033.34     946.79
# 2017-01-01 02:00         962.54      1005.09           1029.51     944.35
# 2017-01-01 03:00         888.44      1002.38            976.34     906.15
# 2017-01-01 04:00         847.10      1002.58            945.28     894.08
#
#                   UES_Center  UES_South
# timestep
# 2017-01-01 00:00     1050.17    1706.30
# 2017-01-01 01:00     1051.15    1592.17
# 2017-01-01 02:00     1039.84    1561.85
# 2017-01-01 03:00      977.04    1534.37
# 2017-01-01 04:00      938.27    1517.58

# %%
"""UES_dayahead_price["datetime"] = pd.to_datetime(UES_dayahead_price["timestep"])
UES_dayahead_price.drop("timestep", axis = 1, inplace = True)
UES_dayahead_price.set_index(["datetime"], drop = True, inplace = True)
UES_dayahead_price.head()
# Out:
#                      UES_Northwest  UES_Siberia  UES_Middle_Volga  UES_Urals  \
# datetime
# 2017-01-01 00:00:00         964.67      1006.27           1032.80     953.23
# 2017-01-01 01:00:00         984.79      1003.79           1033.34     946.79
# 2017-01-01 02:00:00         962.54      1005.09           1029.51     944.35
# 2017-01-01 03:00:00         888.44      1002.38            976.34     906.15
# 2017-01-01 04:00:00         847.10      1002.58            945.28     894.08
#
#                      UES_Center  UES_South
# datetime
# 2017-01-01 00:00:00     1050.17    1706.30
# 2017-01-01 01:00:00     1051.15    1592.17
# 2017-01-01 02:00:00     1039.84    1561.85
# 2017-01-01 03:00:00      977.04    1534.37
# 2017-01-01 04:00:00      938.27    1517.58

# %%
#time series plot
plt.figure(figsize = (20,15))

ax1 = plt.subplot(6, 1, 1)
UES_dayahead_price['UES_Northwest'].plot()
ax1.set_ylabel("UES_Northwest")

ax2 = plt.subplot(6, 1, 2)
UES_dayahead_price['UES_Siberia'].plot()
ax2.set_ylabel("UES_Siberia")

ax3 = plt.subplot(6, 1, 3)
UES_dayahead_price['UES_Middle_Volga'].plot()
ax3.set_ylabel("UES_Middle_Volga")

ax4 = plt.subplot(6, 1, 4)
UES_dayahead_price['UES_Urals'].plot()
ax4.set_ylabel("UES_Urals")

ax5 = plt.subplot(6, 1, 5)
UES_dayahead_price['UES_Center'].plot()
ax5.set_ylabel("UES_Center")

ax6 = plt.subplot(6, 1, 6)
UES_dayahead_price['UES_South'].plot()
ax4.set_ylabel("UES_South")
# Out:
# Text(0, 0.5, 'UES_South')

# %%
intraday_price = UES_intraday_price
intraday_price.head()
# Out:
#                   UES_Northwest  UES_Siberia  UES_Center
# timestep
# 2017-01-01 00:00          767.0        918.0       982.0
# 2017-01-01 01:00          675.0        889.0       848.0
# 2017-01-01 02:00          717.0        933.0       920.0
# 2017-01-01 03:00          683.0        947.0       885.0
# 2017-01-01 04:00          633.0        934.0       829.0

# %%
"""intraday_price["datetime"] = pd.to_datetime(intraday_price["timestep"])
intraday_price.drop("timestep", axis = 1, inplace = True)
intraday_price.set_index(["datetime"], drop = True, inplace = True)
intraday_price.head()
# Out:
#                      UES_Northwest  UES_Siberia  UES_Center
# datetime
# 2017-01-01 00:00:00            767          918         982
# 2017-01-01 01:00:00            675          889         848
# 2017-01-01 02:00:00            717          933         920
# 2017-01-01 03:00:00            683          947         885
# 2017-01-01 04:00:00            633          934         829

# %%
#time series plot
plt.figure(figsize = (15,15))

ax1 = plt.subplot(3, 1, 1)
intraday_price['UES_Northwest'].plot()
ax1.set_ylabel("UES_Northwest")

ax2 = plt.subplot(3, 1, 2)
intraday_price['UES_Siberia'].plot()
ax2.set_ylabel("UES_Siberia")

ax3 = plt.subplot(3, 1, 3)
intraday_price['UES_Center'].plot()
ax3.set_ylabel("UES_Center")
# Out:
# Text(0, 0.5, 'UES_Center')

# %% [markdown]
# # AUTOREGRESSION MODEL

# %% [markdown]
# Since this is a Time series problem, we use an autoregression model.

# %% [markdown]
# ### Check for Autocorrelation using `lag_plot()`

# %%
from pandas.plotting import lag_plot

# %%
# lets do `consumption_eur` first from the dayahead_price_volume data

# first create a dataset with the datetime and consumption_eur
consumption_eur = pd.DataFrame(dayahead_price["consumption_eur"], index = dayahead_price.index)
consumption_eur.head()
# Out:
#                   consumption_eur
# timestep
# 2006-09-03 21:00          70250.0
# 2006-09-03 22:00          66733.0
# 2006-09-05 16:00          72688.0
# 2006-09-05 17:00          71822.0
# 2006-09-05 18:00          71933.0

# %%
lag_plot(consumption_eur)
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### Observation
#
# A cluster of the data on the diagonal shows a high correlation in the dataset.

# %% [markdown]
# Let's do a Further correlation check using Pearson Correlation coeficient .corr())

# %%
values = pd.DataFrame(consumption_eur.values)
data = pd.concat([values.shift(1), values], axis = 1) #creates a dataset of a value -1 and value + 1
data.columns = ["t-1", "t+1"]
result = data.corr()
print(result)
# Out:
#           t-1       t+1
# t-1  1.000000  0.982374
# t+1  0.982374  1.000000

# %% [markdown]
# We can see a high and beautiful correlation

# %% [markdown]
# ### Autocorrelation Plot using `autocorrelation_plot`
# This plots the correlation coefficient for each lag variable. This is a good check to determine which lag variable will be a good fit for a predictive model

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(consumption_eur)
#autocorrelation_plot(, linewidth = 1)
plt.show()

# %% [markdown]
# Further check using the statsmodel `plot_acf`

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(consumption_eur, lags = 51)
plt.show()

# %% [markdown]
# As expected, the power consumptions seem to have a nice symmetrical cyclic pattern.
# The prices though seem to be quite volatile, but not unexpeted certainly.
# The prices also seem to have a lot of values that are zero before the year 2010.
#
# Since we are going to use a form of auto-regression, we are only going to use historical data of any particular attribute to make predictions for that attribute.
#
# Let's do some autocorrelation analysis for each of the four attributes.

# %% [markdown]
# ## Autoregression Model using Statsmodels `AR()`

# %%
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
#dataset 
dataset = consumption_eur.values

#split data with train_test_split
from sklearn.model_selection import train_test_split

#train, test = train_test_split(dataset, shuffle = True, random_state = 42, test_size = 0.2)
train, test = dataset[1: len(dataset) - 30], dataset[len(dataset) - 30:]

# %%
train.shape
# Out:
# (41888, 1)

# %%
test.shape
# Out:
# (30, 1)

# %%
# Train Autoregression for consumption_eur

#model = AutoReg(train, lags = lag_cons)
model = AR(train)
model_fit = model.fit()
print('Coefficients: %s' % model_fit.params)
print('The lag value chose is: %s' % model_fit.k_ar)
# Out:
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 2.26438369e+02  1.43842098e+00 -4.54686466e-01 -1.38582855e-01
#   7.63008922e-02  1.98025452e-02 -1.02250993e-03 -9.54276413e-03
#   3.18572234e-02 -3.53522936e-02  1.74728466e-02 -7.50258794e-04
#   1.58060634e-03  8.85451120e-03 -7.33624932e-02  2.45539103e-02
#   5.70362704e-02  2.61745058e-03 -1.14782908e-02  1.19173268e-02
#   1.14247666e-02 -4.09615004e-02  5.86649219e-02  1.13359271e-01
#   1.39222154e-01 -3.18953323e-01  8.33491970e-03  1.14747131e-01
#  -7.36132383e-02  1.75505909e-02 -1.00766152e-02 -2.32042420e-02
#   2.67734369e-02 -5.79659822e-03  8.32614137e-03  1.56283399e-02
#  -3.15712266e-03 -2.38288914e-02  6.20220714e-02 -5.64068169e-02
#  -3.15276079e-03 -1.09765008e-02 -1.52911505e-02  3.54664892e-02
#  -2.05698546e-02 -3.03408976e-03 -2.89357410e-02  1.05215620e-01
#   8.83472462e-02 -2.05890596e-01  6.12368317e-02 -7.81969002e-03
#   5.75069745e-02 -2.49020133e-02 -1.56245860e-02]
# The lag value chose is: 54

# %%
out = 'AIC: {0:0.3f}, HQIC: {1:0.3f}, BIC: {2:0.3f}'
print(out.format(model_fit.aic, model_fit.hqic, model_fit.bic))
# Out:
# AIC: 13.595, HQIC: 13.598, BIC: 13.606

# %%
# Make Prediction

prediction = model_fit.predict(start=len(train), end = len(train)+len(test)-1, dynamic = False)
prediction
# Out:
# array([104052.5463453 , 103111.51971919, 100913.81573916,  97535.30952236,
#         93454.89146319,  89862.15753879,  87689.56103943,  86100.10295744,
#         85461.44643518,  85785.20126847,  86930.470325  ,  88892.48852602,
#         92325.12499404,  96231.08864803,  99103.89777106, 100422.9637014 ,
#        100537.70182878, 100057.96735496,  99690.95786143,  99564.55214625,
#         99499.60729116,  99499.13423087, 100238.98233288, 101420.18019818,
#        102130.11801252, 101566.45727495,  99758.95704827,  96865.8940567 ,
#         93217.5475409 ,  89887.89157524])

# %%
# Root Mean Squared Error 
rmse = sqrt(mean_squared_error(prediction, test))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 1351.544

# %%
#create a comparison dataframe
for i in range(len(prediction)):
    print('predicted=%f, expected=%f' % (prediction[i], test[i]))
# Out:
# predicted=104052.546345, expected=104170.000000
# predicted=103111.519719, expected=102786.000000
# predicted=100913.815739, expected=100317.000000
# predicted=97535.309522, expected=97671.000000
# predicted=93454.891463, expected=93488.000000
# predicted=89862.157539, expected=89154.000000
# predicted=87689.561039, expected=86639.000000
# predicted=86100.102957, expected=85042.000000
# predicted=85461.446435, expected=84251.000000
# predicted=85785.201268, expected=84334.000000
# predicted=86930.470325, expected=85948.000000
# predicted=88892.488526, expected=87348.000000
# predicted=92325.124994, expected=91732.000000
# predicted=96231.088648, expected=97646.000000
# predicted=99103.897771, expected=101237.000000
# predicted=100422.963701, expected=102659.000000
# predicted=100537.701829, expected=102410.000000
# predicted=100057.967355, expected=101584.000000
# predicted=99690.957861, expected=101366.000000
# predicted=99564.552146, expected=101484.000000
# predicted=99499.607291, expected=101365.000000
# predicted=99499.134231, expected=101124.000000
# predicted=100238.982333, expected=101934.000000
# predicted=101420.180198, expected=103383.000000
# predicted=102130.118013, expected=104068.000000
# predicted=101566.457275, expected=102893.000000
# predicted=99758.957048, expected=100380.000000
# predicted=96865.894057, expected=97864.000000
# predicted=93217.547541, expected=93982.000000
# predicted=89887.891575, expected=89567.000000

# %%
#plot results
plt.plot(test)
plt.plot(prediction, color = "red")

# %%
#calculate r2 score to check goodness of fit
from sklearn.metrics import r2_score

r2 = r2_score(test, prediction)
r2
# Out:
# 0.960400661741684

# %% [markdown]
#    ## 98.8% BEAUTIFUL!!

# %%
prediction
# Out:
# array([104052.5463453 , 103111.51971919, 100913.81573916,  97535.30952236,
#         93454.89146319,  89862.15753879,  87689.56103943,  86100.10295744,
#         85461.44643518,  85785.20126847,  86930.470325  ,  88892.48852602,
#         92325.12499404,  96231.08864803,  99103.89777106, 100422.9637014 ,
#        100537.70182878, 100057.96735496,  99690.95786143,  99564.55214625,
#         99499.60729116,  99499.13423087, 100238.98233288, 101420.18019818,
#        102130.11801252, 101566.45727495,  99758.95704827,  96865.8940567 ,
#         93217.5475409 ,  89887.89157524])

# %%
data_test = dayahead_price["consumption_eur"].tail(30)
data_test = pd.DataFrame(data_test)

# %%
data_test["predicted"] = prediction
data_test
# Out:
#                   consumption_eur      predicted
# timestep
# 2011-11-21 18:00         104170.0  104052.546345
# 2011-11-21 19:00         102786.0  103111.519719
# 2011-11-21 20:00         100317.0  100913.815739
# 2011-11-21 21:00          97671.0   97535.309522
# 2011-11-21 22:00          93488.0   93454.891463
# 2011-11-21 23:00          89154.0   89862.157539
# 2011-11-22 00:00          86639.0   87689.561039
# 2011-11-22 01:00          85042.0   86100.102957
# 2011-11-22 02:00          84251.0   85461.446435
# 2011-11-22 03:00          84334.0   85785.201268
# 2011-11-22 04:00          85948.0   86930.470325
# 2011-11-22 05:00          87348.0   88892.488526
# 2011-11-22 06:00          91732.0   92325.124994
# 2011-11-22 07:00          97646.0   96231.088648
# 2011-11-22 08:00         101237.0   99103.897771
# 2011-11-22 09:00         102659.0  100422.963701
# 2011-11-22 10:00         102410.0  100537.701829
# 2011-11-22 11:00         101584.0  100057.967355
# 2011-11-22 12:00         101366.0   99690.957861
# 2011-11-22 13:00         101484.0   99564.552146
# 2011-11-22 14:00         101365.0   99499.607291
# 2011-11-22 15:00         101124.0   99499.134231
# 2011-11-22 16:00         101934.0  100238.982333
# 2011-11-22 17:00         103383.0  101420.180198
# 2011-11-22 18:00         104068.0  102130.118013
# 2011-11-22 19:00         102893.0  101566.457275
# 2011-11-22 20:00         100380.0   99758.957048
# 2011-11-22 21:00          97864.0   96865.894057
# 2011-11-22 22:00          93982.0   93217.547541
# 2011-11-22 23:00          89567.0   89887.891575

# %%
plt.figure(figsize = (10,5))
plt.plot(data_test["consumption_eur"])
plt.plot(data_test["predicted"])

# %%
plt.figure(figsize = (15,15))

ax1 = plt.subplot(4, 1, 1)
data_test['consumption_eur'].plot()
data_test['predicted'].plot()
ax1.set_title("Consumption Vs Predicted")
# Out:
# Text(0.5, 1.0, 'Consumption Vs Predicted')

# %% [markdown]
# ## I'll create a function to make it easy for other variables
# Let's Go!!!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from sklearn.model_selection import train_test_split
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import r2_score


# first create a dataset with the datetime and consumption_eur

#1. Create datetime dataset
def create_data(dataset, column_name: str):
    global new_data
    new_data = pd.DataFrame(dataset[column_name], index = dataset.index)
    return new_data

#2. plor lag_plot to show correlation

def plot_lag(var):  #takes pandas dataset created above
    lag_plot(var)
    plt.show()
    
#3. confirm correlation with Pearson Correlation Coefficient 

def corr_coef(data): #takes pandas dataset created above
    data = data.copy()
    values = pd.DataFrame(data.values)
    values_data = pd.concat([values.shift(1), values], axis = 1) #creates a dataset of a value -1 and value + 1 
    values_data.columns = ["t-1", "t+1"]
    result = values_data.corr()
    return result

#4. This plots the correlation coefficient for each lag variable. 
#This is a good check to determine which lag variable will be a good fit for a predictive model

def autocorrelation(data_):
    autocorrelation_plot(data_)
    plt.show()
    
#5. Further check using states model
def acf(data_):
    plot_acf(data_, lags = 51)
    plt.show()
    
#6. Autoregression model
def AutoRegres(_data):  #takes new_data
    dataset = _data.values
    #split data with train_test_split
    train, test = dataset[1: len(dataset) - 30], dataset[len(dataset) - 30:]
    
    # Train Autoregression for data and print stats
    model = AR(train)
    model_fit = model.fit()
    print('Coefficients: %s' % model_fit.params)
    print('The lag value chose is: %s' % model_fit.k_ar)
    out = 'AIC: {0:0.3f}, HQIC: {1:0.3f}, BIC: {2:0.3f}'
    print(out.format(model_fit.aic, model_fit.hqic, model_fit.bic))

    # Make Prediction

    prediction = model_fit.predict(start=len(train), end = len(train)+len(test)-1, dynamic = False)
    
    # Root Mean Squared Error 
    rmse = sqrt(mean_squared_error(prediction, test))
    print('Test RMSE: %.3f' % rmse)

    #create a comparison dataframe
    for i in range(len(prediction)):
        print('predicted=%f, expected=%f' % (prediction[i], test[i]))

    #plot results
    plt.plot(test)
    plt.plot(prediction, color = "red")
    
    #calculate r2 score to check goodness of fit
    r2 = r2_score(test, prediction)
    return r2

# %%
#Consumption_sib 

create_data(dayahead_price, "consumption_sib")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 1.88213636e+01  1.22505529e+00 -2.73012479e-01 -1.16834141e-01
#   1.46602083e-02  7.67654488e-03  1.43391578e-02  1.73530546e-02
#   2.27616403e-02  2.23732769e-03 -1.10670772e-02  2.68839171e-02
#  -2.81422851e-02  2.01189171e-02 -5.57936530e-02  3.93658418e-02
#  -5.28286656e-04  4.55399886e-02 -1.94852436e-02  1.74992549e-02
#  -9.05259340e-03 -7.25430041e-03  5.40656289e-02  9.81020424e-02
#   1.90499432e-01 -2.95263717e-01  4.10106009e-03  6.15027685e-02
#  -2.53863414e-02  7.20870534e-03 -1.96485272e-02 -9.79880060e-03
#  -1.08224600e-02  6.79764543e-03 -7.29234176e-03  1.44638407e-02
#   1.26861139e-02 -1.53467448e-02  5.07329415e-03  1.90264330e-03
#  -2.79366419e-02 -4.72079809e-03 -1.90047634e-02  2.87000526e-02
#  -1.04753891e-02 -1.98277416e-02 -1.07456539e-02  7.43383185e-02
#   1.36369507e-01 -1.73839667e-01 -7.90811168e-03  1.44064013e-02
#   5.01914694e-02  1.25843403e-02 -4.81244559e-02]
# The lag value chose is: 54
# AIC: 10.386, HQIC: 10.390, BIC: 10.398
# Test RMSE: 290.077
# predicted=25247.099712, expected=25293.000000
# predicted=24524.843602, expected=24490.000000
# predicted=23908.558255, expected=23659.000000
# predicted=23457.026842, expected=23177.000000
# predicted=23156.705407, expected=22860.000000
# predicted=23055.420773, expected=22732.000000
# predicted=23137.499243, expected=22639.000000
# predicted=23460.560385, expected=22831.000000
# predicted=24007.826367, expected=23469.000000
# predicted=24595.017320, expected=24301.000000
# predicted=25215.130043, expected=25254.000000
# predicted=25647.516983, expected=25904.000000
# predicted=25794.980845, expected=26150.000000
# predicted=25695.408159, expected=25975.000000
# predicted=25527.406938, expected=25760.000000
# predicted=25367.537618, expected=25542.000000
# predicted=25275.849540, expected=25382.000000
# predicted=25240.138045, expected=25309.000000
# predicted=25340.706494, expected=25319.000000
# predicted=25729.196263, expected=25626.000000
# predicted=26258.690008, expected=26042.000000
# predicted=26538.909262, expected=26396.000000
# predicted=26387.579602, expected=26306.000000
# predicted=25934.098814, expected=26022.000000
# predicted=25270.651806, expected=25464.000000
# predicted=24590.724156, expected=24530.000000
# predicted=23968.105116, expected=23645.000000
# predicted=23479.661573, expected=23085.000000
# predicted=23142.010123, expected=22700.000000
# predicted=23004.245310, expected=22552.000000
# 0.9510750345866267

# %%
#price_eur

create_data(dayahead_price, "price_eur")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 5.40093418e+00  8.83166766e-01 -1.00572825e-03  1.18493350e-02
#  -4.04160049e-04 -7.43216020e-03  5.31869138e-03 -3.25222992e-04
#   7.03118479e-03 -2.28550291e-02  2.47897791e-03  1.15365695e-02
#   9.28264580e-03 -2.66033456e-02 -5.44765815e-03 -6.26858331e-03
#  -5.81955838e-03  1.29897477e-02 -1.37846073e-03  1.28686919e-02
#   1.20194568e-02  2.22131497e-02  3.16693933e-02  8.52286194e-02
#   2.67611219e-01 -2.20849724e-01 -7.43163407e-02 -4.32028025e-02
#   2.36915862e-03 -1.88143753e-02  3.72250945e-03 -1.74548569e-02
#   1.79156991e-02  7.67770329e-03 -4.02170314e-03  1.00652081e-03
#   2.52858582e-02 -1.09674818e-02  7.44907218e-03  8.25326436e-04
#  -1.08459952e-02  6.91579701e-03 -2.91701537e-03 -1.25783085e-02
#  -1.11492629e-02 -1.29232554e-02  1.47839697e-02  3.31169823e-02
#   1.00087190e-01 -7.58514661e-02 -1.93709673e-02  6.51466911e-03
#  -1.38066896e-02  2.16206985e-02 -6.97184128e-03 -1.59148865e-03
#   3.29699397e-03]
# The lag value chose is: 56
# AIC: 7.620, HQIC: 7.623, BIC: 7.631
# Test RMSE: 47.486
# predicted=1030.622913, expected=1030.410000
# predicted=1007.055505, expected=985.640000
# predicted=968.613165, expected=963.430000
# predicted=933.715179, expected=914.720000
# predicted=887.953280, expected=839.430000
# predicted=824.326427, expected=771.910000
# predicted=779.785425, expected=681.610000
# predicted=715.992039, expected=610.180000
# predicted=676.752415, expected=571.180000
# predicted=661.911190, expected=563.900000
# predicted=666.727541, expected=628.910000
# predicted=665.387006, expected=686.090000
# predicted=735.549638, expected=784.370000
# predicted=848.114986, expected=906.400000
# predicted=910.043423, expected=960.510000
# predicted=944.452508, expected=975.460000
# predicted=947.991210, expected=973.310000
# predicted=942.757997, expected=971.280000
# predicted=943.270480, expected=965.120000
# predicted=941.664534, expected=970.640000
# predicted=942.252681, expected=970.880000
# predicted=947.428619, expected=961.240000
# predicted=958.816597, expected=975.980000
# predicted=983.823361, expected=976.200000
# predicted=988.172482, expected=978.500000
# predicted=975.231222, expected=964.730000
# predicted=947.665466, expected=948.680000
# predicted=915.816396, expected=891.810000
# predicted=873.873921, expected=837.580000
# predicted=820.252008, expected=767.980000
# 0.884582614169589

# %%
#price_sib

create_data(dayahead_price, "price_sib")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 5.83442389e+00  8.45661186e-01  2.74560413e-02  4.84596729e-03
#  -2.55654347e-02  2.38792427e-02  1.77978985e-02  1.83806706e-02
#  -1.40309188e-02  1.98275089e-02 -3.59104614e-03  1.43575586e-02
#  -5.85483993e-03  3.52465085e-03 -2.48337710e-02  1.81834327e-02
#  -3.88845118e-02  6.45243691e-03  2.31539815e-02  1.35475395e-02
#   2.30961828e-02  1.41829428e-02  1.92056528e-02  3.65474733e-02
#   9.76432369e-02 -7.36432169e-02 -4.87135194e-02 -2.32356532e-02
#   1.92502197e-02 -2.97841920e-02 -4.70470248e-03  1.40867270e-02
#  -1.91870113e-02 -1.65098890e-02  2.61829086e-02  5.72351227e-03
#  -5.67272920e-03  3.60906565e-03  5.84146285e-03 -5.26773461e-03
#  -6.56826389e-03 -1.09352901e-03 -1.36914989e-03  2.62938743e-03
#  -5.00503452e-03  4.61815379e-03  2.23844879e-02  3.27060720e-02
#   2.20416524e-02 -8.03455799e-03 -2.22575113e-04 -4.61422524e-03
#  -8.61857150e-03 -1.04396436e-02 -1.37520276e-02]
# The lag value chose is: 54
# AIC: 6.647, HQIC: 6.651, BIC: 6.658
# Test RMSE: 29.166
# predicted=569.440019, expected=589.510000
# predicted=567.768136, expected=575.950000
# predicted=566.308110, expected=567.420000
# predicted=562.237153, expected=561.330000
# predicted=560.695496, expected=552.770000
# predicted=556.908705, expected=551.240000
# predicted=553.317378, expected=541.610000
# predicted=554.628537, expected=542.470000
# predicted=561.198619, expected=554.330000
# predicted=564.475538, expected=580.740000
# predicted=566.114542, expected=632.930000
# predicted=566.684434, expected=639.800000
# predicted=568.102442, expected=636.860000
# predicted=568.682224, expected=590.030000
# predicted=567.685821, expected=590.660000
# predicted=568.538621, expected=587.740000
# predicted=567.672558, expected=587.420000
# predicted=567.058298, expected=585.690000
# predicted=567.039663, expected=579.690000
# predicted=569.300603, expected=630.330000
# predicted=570.338236, expected=565.620000
# predicted=571.551968, expected=579.680000
# predicted=569.889465, expected=622.970000
# predicted=566.820896, expected=582.360000
# predicted=564.299860, expected=583.820000
# predicted=562.191624, expected=568.850000
# predicted=560.267408, expected=560.380000
# predicted=557.436248, expected=552.500000
# predicted=554.862751, expected=543.950000
# predicted=551.893929, expected=540.600000
# -0.0455908652633763

# %%
UES_dayahead_price.head()
# Out:
#                      UES_Northwest  UES_Siberia  UES_Middle_Volga  UES_Urals  \
# datetime
# 2017-01-01 00:00:00         964.67      1006.27           1032.80     953.23
# 2017-01-01 01:00:00         984.79      1003.79           1033.34     946.79
# 2017-01-01 02:00:00         962.54      1005.09           1029.51     944.35
# 2017-01-01 03:00:00         888.44      1002.38            976.34     906.15
# 2017-01-01 04:00:00         847.10      1002.58            945.28     894.08
#
#                      UES_Center  UES_South
# datetime
# 2017-01-01 00:00:00     1050.17    1706.30
# 2017-01-01 01:00:00     1051.15    1592.17
# 2017-01-01 02:00:00     1039.84    1561.85
# 2017-01-01 03:00:00      977.04    1534.37
# 2017-01-01 04:00:00      938.27    1517.58

# %%
#UES_dayahead_price UES_Northwest 

create_data(UES_dayahead_price, "UES_Northwest")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 3.60282133e+01  7.63176311e-01 -1.59672207e-03 -7.34789540e-03
#   1.04428997e-02  1.79447976e-02 -2.33419760e-02  2.80585421e-02
#   1.32747336e-02 -4.58144233e-02  2.00660799e-02  3.02389184e-02
#   2.04666784e-03 -3.54838528e-02  1.45855934e-02 -3.32242280e-02
#   6.70840287e-03  4.63252822e-03  6.64146972e-03  7.77856418e-03
#   1.73886181e-02  2.37327252e-02  3.57071274e-02  8.70778781e-02
#   2.25730212e-01 -1.23380424e-01 -7.62499735e-02 -4.10598739e-02
#   1.90274889e-03 -1.96108986e-02 -2.26598193e-03 -1.72236611e-02
#  -4.58704755e-03 -1.68112645e-02  1.44866518e-02 -8.48673019e-03
#   3.75236602e-02 -8.60115197e-04 -1.69202563e-02 -8.58626593e-03
#   1.43207677e-02 -1.05728538e-02 -8.04019637e-03  1.18866762e-02
#  -1.33429956e-02 -2.20585627e-02  2.13590068e-02  8.90491256e-02]
# The lag value chose is: 47
# AIC: 8.804, HQIC: 8.810, BIC: 8.821
# Test RMSE: 72.115
# predicted=1368.695330, expected=1427.040000
# predicted=1395.174138, expected=1491.760000
# predicted=1401.771086, expected=1454.970000
# predicted=1383.286463, expected=1495.590000
# predicted=1293.891954, expected=1437.430000
# predicted=1154.557342, expected=1132.340000
# predicted=1024.903012, expected=1002.290000
# predicted=944.420871, expected=931.020000
# predicted=903.626236, expected=879.140000
# predicted=902.668084, expected=886.050000
# predicted=947.885461, expected=929.260000
# predicted=1036.698424, expected=1001.410000
# predicted=1153.556994, expected=1232.960000
# predicted=1252.478579, expected=1223.790000
# predicted=1367.933019, expected=1334.080000
# predicted=1466.766991, expected=1477.550000
# predicted=1505.618064, expected=1519.170000
# predicted=1488.968255, expected=1510.600000
# predicted=1450.482813, expected=1452.370000
# predicted=1446.101664, expected=1438.690000
# predicted=1446.126381, expected=1392.160000
# predicted=1442.201578, expected=1534.980000
# predicted=1408.443302, expected=1406.120000
# predicted=1368.045437, expected=1321.410000
# predicted=1363.106704, expected=1381.080000
# predicted=1369.596471, expected=1485.020000
# predicted=1372.795083, expected=1421.090000
# predicted=1343.450531, expected=1496.800000
# predicted=1252.846406, expected=1442.770000
# predicted=1130.564476, expected=1202.820000
# 0.8831704644103935

# %%
#UES_dayahead_price UES_Siberia

create_data(UES_dayahead_price, "UES_Siberia")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 6.62620286e+00  8.98450889e-01  2.79749238e-02 -6.16589473e-02
#   3.07307920e-02 -8.33989426e-03 -2.94174835e-03  4.95289959e-03
#   2.66775409e-02 -1.75911580e-02 -3.09881465e-03  2.05899131e-02
#  -1.14992970e-02  7.77746473e-03 -1.05564080e-02 -1.77504113e-02
#   1.70231019e-02  1.61340791e-03  1.34070189e-02  2.97707219e-02
#   1.60148558e-02  1.74501750e-02  1.01009437e-02  7.70128223e-02
#   5.27716574e-02 -6.41822720e-02 -2.52677382e-02 -4.01955594e-02
#  -3.03713427e-02  5.95402518e-03 -2.91711852e-02 -2.24505083e-03
#   5.29229872e-03  7.04178730e-03 -2.37265195e-03  2.54513527e-03
#  -4.27906297e-03  2.92203704e-03 -1.61033964e-03 -2.72355189e-03
#  -2.10459024e-03 -1.08138008e-02 -1.42036321e-02 -4.37025849e-03
#   3.58282505e-04  1.30713983e-02  5.49441892e-02  1.53212774e-02]
# The lag value chose is: 47
# AIC: 6.860, HQIC: 6.865, BIC: 6.877
# Test RMSE: 56.551
# predicted=555.928452, expected=569.760000
# predicted=493.151914, expected=526.540000
# predicted=445.266429, expected=476.070000
# predicted=404.030321, expected=456.010000
# predicted=382.602534, expected=444.220000
# predicted=382.513798, expected=379.210000
# predicted=387.387812, expected=307.570000
# predicted=410.129718, expected=415.770000
# predicted=448.468798, expected=463.230000
# predicted=495.407945, expected=485.480000
# predicted=533.002190, expected=517.910000
# predicted=554.756796, expected=538.960000
# predicted=570.680311, expected=591.840000
# predicted=579.569226, expected=588.690000
# predicted=588.777539, expected=586.160000
# predicted=599.402766, expected=584.810000
# predicted=609.471863, expected=584.210000
# predicted=626.723831, expected=585.340000
# predicted=641.011377, expected=588.010000
# predicted=658.499923, expected=594.550000
# predicted=673.910719, expected=595.900000
# predicted=671.902172, expected=614.830000
# predicted=655.957137, expected=631.060000
# predicted=621.467127, expected=597.560000
# predicted=578.653712, expected=545.800000
# predicted=535.196426, expected=500.910000
# predicted=498.126273, expected=446.520000
# predicted=469.498308, expected=418.140000
# predicted=451.728497, expected=306.680000
# predicted=449.698092, expected=274.060000
# 0.6608589247741647

# %%
#UES_dayahead_price UES_Middle_Volga

create_data(UES_dayahead_price, "UES_Middle_Volga")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 2.99147492e+01  9.80272651e-01 -1.12001720e-01 -2.48417804e-02
#  -1.03265283e-02  1.54840815e-03  1.43307414e-02 -1.08197559e-02
#   4.02070863e-02 -3.33988619e-02 -1.04224164e-02  2.20172044e-02
#  -3.01174339e-03 -2.67794290e-03 -1.95983779e-02 -3.96698245e-02
#   5.13149571e-03 -1.23571180e-02  1.67548147e-02  4.43959271e-02
#   2.33592375e-02 -1.15525542e-02  3.97774655e-02  8.04053483e-02
#   3.05842013e-01 -2.90003122e-01 -6.33348790e-02 -1.08995433e-02
#   1.68421582e-02 -2.26942189e-03 -1.16291068e-02 -1.59572780e-02
#  -1.79835866e-02 -8.75050331e-03  4.09758041e-02  8.03487851e-03
#  -3.30071247e-03  1.32166207e-02 -1.39811628e-02  4.40919815e-03
#   2.21421183e-02  1.13398058e-02 -1.49754021e-02 -1.50007260e-02
#  -4.07261386e-02  3.49184786e-03  1.04326436e-02  7.06803492e-02]
# The lag value chose is: 47
# AIC: 7.860, HQIC: 7.865, BIC: 7.876
# Test RMSE: 69.423
# predicted=1501.426413, expected=1542.880000
# predicted=1500.954576, expected=1614.280000
# predicted=1443.487990, expected=1586.240000
# predicted=1382.637162, expected=1475.020000
# predicted=1290.574432, expected=1446.440000
# predicted=1134.254152, expected=1203.490000
# predicted=992.129715, expected=997.820000
# predicted=928.365435, expected=944.030000
# predicted=918.723031, expected=896.670000
# predicted=944.751709, expected=912.590000
# predicted=1009.195839, expected=967.990000
# predicted=1127.589365, expected=1059.260000
# predicted=1306.237748, expected=1350.040000
# predicted=1465.386779, expected=1396.590000
# predicted=1563.618829, expected=1469.600000
# predicted=1617.634032, expected=1578.730000
# predicted=1620.757444, expected=1585.160000
# predicted=1594.459233, expected=1566.710000
# predicted=1573.051157, expected=1537.540000
# predicted=1549.213187, expected=1545.960000
# predicted=1524.720913, expected=1509.020000
# predicted=1507.641016, expected=1554.540000
# predicted=1482.244573, expected=1484.790000
# predicted=1468.597033, expected=1468.800000
# predicted=1474.772023, expected=1519.730000
# predicted=1468.469701, expected=1527.610000
# predicted=1429.621333, expected=1474.500000
# predicted=1363.142635, expected=1453.970000
# predicted=1260.201022, expected=1400.690000
# predicted=1126.592051, expected=1201.260000
# 0.9073699923750727

# %%
#UES_dayahead_price UES_Urals

create_data(UES_dayahead_price, "UES_Urals")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 2.59514689e+01  1.02407674e+00 -1.09010650e-01 -4.65286252e-02
#  -4.02300537e-03 -2.17596743e-03  4.30734454e-03 -2.98063442e-04
#   3.87008429e-02 -3.84994952e-02  4.70718652e-03  2.17319258e-02
#  -1.48337750e-02 -1.66643470e-02 -3.23969968e-02  7.04120934e-03
#  -1.90611287e-02  2.02425341e-02 -4.18482718e-03  3.97039668e-02
#   1.18664640e-02  4.99208917e-03  4.25315460e-02  5.19655203e-02
#   2.39234367e-01 -2.18133661e-01 -4.60142642e-02 -3.08500060e-02
#  -6.29195789e-03 -4.14861986e-04  3.57278063e-03 -1.06168834e-02
#  -1.75234723e-02  2.64907325e-03  1.60657594e-03  3.38179919e-02
#  -1.14211794e-03  1.67403005e-02 -1.73390720e-02  3.72703130e-03
#   1.33125087e-02 -4.53935748e-03  4.44369085e-03 -3.23638929e-02
#  -1.35510848e-02  4.64210666e-03  3.18905962e-02  3.46155593e-02]
# The lag value chose is: 47
# AIC: 7.078, HQIC: 7.084, BIC: 7.095
# Test RMSE: 57.838
# predicted=1278.534450, expected=1340.790000
# predicted=1244.209042, expected=1293.330000
# predicted=1179.330076, expected=1244.740000
# predicted=1104.945211, expected=1174.260000
# predicted=1040.468216, expected=1045.360000
# predicted=975.099536, expected=977.010000
# predicted=927.153787, expected=909.420000
# predicted=895.811951, expected=885.480000
# predicted=890.766589, expected=860.410000
# predicted=912.669453, expected=884.970000
# predicted=963.789973, expected=920.990000
# predicted=1038.752908, expected=968.530000
# predicted=1151.749910, expected=1160.370000
# predicted=1225.088069, expected=1178.670000
# predicted=1281.403172, expected=1203.030000
# predicted=1326.284007, expected=1235.270000
# predicted=1332.839229, expected=1231.630000
# predicted=1324.176772, expected=1227.530000
# predicted=1307.653932, expected=1214.550000
# predicted=1294.060761, expected=1213.740000
# predicted=1281.844967, expected=1198.470000
# predicted=1281.780560, expected=1229.990000
# predicted=1278.843768, expected=1236.950000
# predicted=1263.357206, expected=1229.480000
# predicted=1242.257611, expected=1239.560000
# predicted=1206.359947, expected=1207.240000
# predicted=1150.435461, expected=1060.060000
# predicted=1084.719885, expected=1022.530000
# predicted=1019.557583, expected=1022.250000
# predicted=957.310306, expected=969.080000
# 0.8287658737384527

# %%
#UES_dayahead_price UES_Center

create_data(UES_dayahead_price, "UES_Center")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 3.88829432e+01  9.42624579e-01 -8.47058429e-02 -1.99860420e-02
#  -7.30702568e-03 -7.60768723e-03  1.14161867e-02 -1.04187061e-03
#   5.20357546e-02 -6.17248129e-02 -2.20602734e-03  2.91298157e-02
#   1.69517840e-03 -1.57900240e-02 -9.22079061e-03 -4.09306467e-02
#  -6.47080223e-03 -1.48213920e-02  2.74095879e-02  4.72226993e-02
#   2.24480643e-02 -7.01266390e-03  3.29911950e-02  7.89325356e-02
#   3.27403783e-01 -2.82800997e-01 -9.03811104e-02 -2.74242450e-03
#   4.73650457e-03  1.22630878e-02 -1.10598144e-02 -2.56491973e-02
#  -1.70094414e-02 -4.06655827e-03  4.01667235e-02  1.11122201e-03
#   8.10654470e-03  1.56921517e-03 -1.38125252e-02  5.39509120e-03
#   4.15967450e-02 -3.31062342e-03 -9.87770358e-03 -3.03755474e-02
#  -3.43439673e-02 -1.20561514e-03  9.16799854e-03  7.86346154e-02]
# The lag value chose is: 47
# AIC: 8.193, HQIC: 8.199, BIC: 8.210
# Test RMSE: 64.099
# predicted=1489.034277, expected=1568.260000
# predicted=1518.738558, expected=1623.150000
# predicted=1502.756037, expected=1587.270000
# predicted=1482.766586, expected=1576.130000
# predicted=1387.703371, expected=1524.990000
# predicted=1196.787579, expected=1195.310000
# predicted=1059.022218, expected=1030.850000
# predicted=988.281333, expected=970.650000
# predicted=960.020477, expected=916.920000
# predicted=970.672589, expected=922.930000
# predicted=1013.867455, expected=969.470000
# predicted=1109.154363, expected=1050.470000
# predicted=1264.580333, expected=1318.270000
# predicted=1367.253919, expected=1320.300000
# predicted=1486.251643, expected=1428.700000
# predicted=1597.960399, expected=1577.480000
# predicted=1632.392215, expected=1610.160000
# predicted=1621.803812, expected=1594.170000
# predicted=1577.484209, expected=1553.810000
# predicted=1579.380527, expected=1545.920000
# predicted=1580.909058, expected=1494.030000
# predicted=1568.076474, expected=1591.740000
# predicted=1531.545162, expected=1472.160000
# predicted=1476.605903, expected=1410.480000
# predicted=1472.135837, expected=1487.600000
# predicted=1488.370422, expected=1571.060000
# predicted=1483.135293, expected=1505.240000
# predicted=1451.101165, expected=1532.050000
# predicted=1349.814661, expected=1479.390000
# predicted=1192.383667, expected=1237.590000
# 0.9233622577383463

# %%
#UES_dayahead_price UES_South

create_data(UES_dayahead_price, "UES_South")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 6.74577025e+01  8.14797128e-01 -1.00156274e-01  3.69013685e-02
#  -1.24914966e-02  2.69382972e-03  1.36972451e-02 -7.55611725e-03
#  -4.60102599e-03 -1.57472443e-02  2.99858431e-02  6.60690198e-02
#  -3.01644488e-02 -2.24211240e-02 -3.48163182e-02  6.73508849e-03
#  -2.38991618e-02 -5.88035228e-03  1.63141921e-02  3.05992517e-02
#   1.98913551e-02  7.31348242e-03  7.65982744e-02  3.80303928e-02
#   2.53537935e-01 -1.29921024e-01 -5.67332395e-02 -2.76818141e-02
#   1.97373354e-03 -1.14008906e-02 -9.28389027e-03 -1.97824354e-02
#  -1.45853021e-02  1.29030457e-03 -8.83995705e-03 -1.32847706e-02
#   1.80565581e-02  3.79731117e-02 -1.23125105e-02 -2.20388977e-02
#   9.98822709e-03 -8.18441693e-04  2.21887804e-02 -1.56998900e-02
#  -3.31296071e-02 -2.97693031e-03 -7.35935329e-03  9.39328135e-02]
# The lag value chose is: 47
# AIC: 9.328, HQIC: 9.334, BIC: 9.345
# Test RMSE: 68.820
# predicted=1610.206775, expected=1657.110000
# predicted=1641.933222, expected=1674.960000
# predicted=1629.740099, expected=1658.680000
# predicted=1573.381011, expected=1654.640000
# predicted=1432.986002, expected=1582.680000
# predicted=1202.380137, expected=1171.840000
# predicted=1046.562147, expected=1016.680000
# predicted=989.912766, expected=1003.070000
# predicted=969.145613, expected=972.550000
# predicted=976.735650, expected=971.060000
# predicted=1022.213508, expected=998.690000
# predicted=1096.001550, expected=1051.330000
# predicted=1257.683466, expected=1321.230000
# predicted=1415.510463, expected=1361.090000
# predicted=1564.771682, expected=1582.600000
# predicted=1650.657672, expected=1654.760000
# predicted=1674.413140, expected=1654.990000
# predicted=1663.603530, expected=1648.490000
# predicted=1636.986563, expected=1641.610000
# predicted=1635.592184, expected=1640.740000
# predicted=1643.719616, expected=1614.880000
# predicted=1644.015573, expected=1642.120000
# predicted=1634.559418, expected=1613.290000
# predicted=1617.710080, expected=1540.270000
# predicted=1619.495798, expected=1668.720000
# predicted=1635.987939, expected=1733.100000
# predicted=1621.424166, expected=1685.830000
# predicted=1559.958570, expected=1729.720000
# predicted=1417.117870, expected=1606.880000
# predicted=1233.656380, expected=1324.500000
# 0.9326558744514155

# %%
intraday_price.head()
# Out:
#                      UES_Northwest  UES_Siberia  UES_Center
# datetime
# 2017-01-01 00:00:00            767          918         982
# 2017-01-01 01:00:00            675          889         848
# 2017-01-01 02:00:00            717          933         920
# 2017-01-01 03:00:00            683          947         885
# 2017-01-01 04:00:00            633          934         829

# %%
#UES_intraday_price UES_Northwest

create_data(intraday_price, "UES_Northwest")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 5.72684376e+01  7.46514082e-01  6.28765343e-02  2.44510595e-02
#  -1.69390340e-02 -8.82661220e-03 -3.17659053e-02 -1.37710781e-02
#   7.54399148e-03 -2.60716958e-02  1.98925071e-02  1.49419900e-02
#   1.29043630e-02 -3.01287963e-02 -2.64109110e-02  1.13819908e-02
#   7.48409339e-03 -6.60846094e-03  2.99760728e-02  2.06087125e-02
#   2.36218358e-02  5.47696664e-03  4.40981380e-02  7.45267739e-02
#   8.51806220e-02 -1.06156410e-01 -4.73264171e-02 -1.08130245e-02
#  -4.39573565e-04 -7.32132054e-04 -7.56048391e-04  5.70694743e-03
#  -1.63626113e-05  1.59994412e-02 -1.20293365e-02  2.65300126e-03
#  -4.93504564e-04  1.17081328e-02 -9.31388782e-03 -5.45851324e-03
#  -3.31685360e-05  6.14698949e-03 -1.13242627e-02  1.34324600e-02
#  -1.08670887e-02  2.04784715e-02  3.29126599e-04  5.15333306e-02]
# The lag value chose is: 47
# AIC: 9.863, HQIC: 9.868, BIC: 9.880
# Test RMSE: 182.210
# predicted=1158.076780, expected=1014.000000
# predicted=1158.528876, expected=1052.000000
# predicted=1145.240982, expected=1185.000000
# predicted=1149.597402, expected=1223.000000
# predicted=1150.480941, expected=1299.000000
# predicted=1169.748212, expected=1513.000000
# predicted=1180.372208, expected=1158.000000
# predicted=1105.823552, expected=1161.000000
# predicted=1000.289197, expected=946.000000
# predicted=898.266769, expected=649.000000
# predicted=854.239727, expected=614.000000
# predicted=834.248408, expected=794.000000
# predicted=805.148680, expected=889.000000
# predicted=807.550822, expected=1005.000000
# predicted=848.099221, expected=1063.000000
# predicted=903.006790, expected=1181.000000
# predicted=957.408487, expected=1167.000000
# predicted=1011.949174, expected=1093.000000
# predicted=1073.616872, expected=1088.000000
# predicted=1119.602886, expected=953.000000
# predicted=1123.585216, expected=1061.000000
# predicted=1100.084614, expected=1021.000000
# predicted=1118.926242, expected=1080.000000
# predicted=1140.065582, expected=1027.000000
# predicted=1145.337907, expected=903.000000
# predicted=1138.489641, expected=968.000000
# predicted=1134.583661, expected=852.000000
# predicted=1132.888706, expected=890.000000
# predicted=1134.629722, expected=928.000000
# predicted=1136.861315, expected=753.000000
# 0.019652796370281278

# %%
#UES_intraday_price UES_Siberia

create_data(intraday_price, "UES_Siberia")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 3.10344392e+01  5.28359928e-01  1.26691212e-01  4.33218117e-02
#   2.79993886e-02  1.11309497e-02 -1.08235251e-03  6.89850835e-03
#   1.65519563e-02 -4.71560334e-06  7.91917567e-03  8.42959072e-03
#  -1.94909381e-03  3.74477438e-03  7.46852581e-05 -4.93648165e-03
#   4.22872858e-03 -1.12466811e-02  8.67205348e-03  2.30556137e-02
#   1.88120696e-02  1.23392279e-02  1.73389517e-02  6.21904384e-02
#   2.84386776e-01 -1.02582244e-01 -7.48239719e-02 -4.48149104e-02
#  -9.75961098e-03 -2.01264351e-02 -2.75522476e-02 -7.43557730e-03
#  -5.77174668e-03 -1.43948319e-02 -9.84317403e-03  1.96617616e-02
#  -4.16098376e-04  2.25173128e-03 -2.03340991e-02 -9.57451920e-04
#   7.25364182e-03 -3.97483664e-03 -1.43097257e-02 -2.44150475e-03
#   3.73418740e-03 -1.10799407e-02  2.82333660e-02  7.74357359e-02]
# The lag value chose is: 47
# AIC: 9.720, HQIC: 9.726, BIC: 9.737
# Test RMSE: 233.178
# predicted=551.132368, expected=505.000000
# predicted=384.001792, expected=519.000000
# predicted=284.419219, expected=199.000000
# predicted=202.243587, expected=579.000000
# predicted=271.236673, expected=0.000000
# predicted=425.277575, expected=0.000000
# predicted=408.944926, expected=0.000000
# predicted=521.562844, expected=0.000000
# predicted=572.736371, expected=526.000000
# predicted=655.950798, expected=281.000000
# predicted=688.960205, expected=863.000000
# predicted=733.551307, expected=718.000000
# predicted=765.783225, expected=761.000000
# predicted=794.661495, expected=719.000000
# predicted=815.268690, expected=668.000000
# predicted=825.897192, expected=503.000000
# predicted=826.878305, expected=706.000000
# predicted=845.836806, expected=710.000000
# predicted=861.680932, expected=652.000000
# predicted=880.145116, expected=716.000000
# predicted=901.385145, expected=932.000000
# predicted=857.944980, expected=748.000000
# predicted=843.466583, expected=740.000000
# predicted=731.914845, expected=443.000000
# predicted=592.355377, expected=426.000000
# predicted=464.025921, expected=509.000000
# predicted=368.703953, expected=535.000000
# predicted=341.438314, expected=287.000000
# predicted=375.146258, expected=266.000000
# predicted=423.638156, expected=0.000000
# 0.2857311982146381

# %%
#UES_intraday_price UES_Center

create_data(intraday_price, "UES_Center")
plot_lag(new_data)
corr_coef(new_data)
autocorrelation(new_data)
acf(new_data)
AutoRegres(new_data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Coefficients: [ 8.31315048e+01  8.52352509e-01 -1.50219194e-02  2.94450789e-03
#  -2.35618398e-02 -1.83550684e-02 -2.52511291e-02 -1.16378659e-05
#   1.02563207e-02 -4.33116327e-02  1.81310960e-02  2.37436419e-02
#   4.88906323e-03 -3.31953245e-02 -3.29384265e-02  1.89383522e-02
#  -5.66975266e-03  7.86526816e-04  5.22576333e-02  2.22835199e-02
#   9.44805792e-03  1.11664650e-02  3.00576260e-02  8.21201369e-02
#   1.03604168e-01 -1.36950478e-01 -5.57471678e-02  6.35908787e-03
#   3.44122438e-03 -6.06426782e-04  4.82859858e-03 -1.43494168e-02
#   1.62759764e-02  6.01371190e-03  1.25683420e-03  9.37477834e-03
#   6.72586249e-03 -1.29939555e-03 -1.57867507e-02  2.53756350e-03
#  -2.75320240e-03  4.56351862e-03 -2.90471478e-02  2.09831501e-02
#  -2.33686262e-02  2.38622830e-02  1.06957172e-02  4.97812010e-02]
# The lag value chose is: 47
# AIC: 9.836, HQIC: 9.841, BIC: 9.853
# Test RMSE: 210.349
# predicted=1243.223075, expected=1191.000000
# predicted=1273.231821, expected=1237.000000
# predicted=1300.770343, expected=1237.000000
# predicted=1298.162112, expected=1276.000000
# predicted=1286.219337, expected=1354.000000
# predicted=1289.727560, expected=1567.000000
# predicted=1313.105469, expected=1187.000000
# predicted=1231.374242, expected=1188.000000
# predicted=1104.737462, expected=990.000000
# predicted=996.567344, expected=747.000000
# predicted=946.408645, expected=704.000000
# predicted=919.366782, expected=923.000000
# predicted=882.360675, expected=1023.000000
# predicted=886.434712, expected=1154.000000
# predicted=932.944147, expected=1277.000000
# predicted=995.338484, expected=1301.000000
# predicted=1060.822343, expected=1268.000000
# predicted=1129.321083, expected=1184.000000
# predicted=1210.078585, expected=1183.000000
# predicted=1275.581645, expected=1170.000000
# predicted=1292.848155, expected=1147.000000
# predicted=1288.506285, expected=1107.000000
# predicted=1300.236466, expected=1135.000000
# predicted=1296.981243, expected=1090.000000
# predicted=1294.245467, expected=1031.000000
# predicted=1303.590117, expected=1166.000000
# predicted=1304.978310, expected=998.000000
# predicted=1300.226095, expected=978.000000
# predicted=1295.510522, expected=1002.000000
# predicted=1294.023870, expected=817.000000
# -0.409763420981208
